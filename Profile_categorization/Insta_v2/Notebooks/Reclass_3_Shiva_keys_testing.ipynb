# %%
import pandas as pd
import numpy as np
from collections import Counter
import nltk
import psycopg2
from nltk.corpus import stopwords
import re
from itertools import chain 
import math
import time
import logging 
import requests
import json
print("Imported all packages.")
print("Loading GoogleNews...")
from gensim import models
w = models.KeyedVectors.load_word2vec_format(r"F:\Pretrained Models\GoogleNews-vectors-negative300.bin.gz", binary=True, limit=2100000)
print("Loaded GoogleNews!")
# Out:
# Imported all packages.
# Loading GoogleNews...
# Loaded GoogleNews!

# %% [markdown]
# food_tags = ['food', 'recipes', 'recipe', 'cooking', 'fried']
# fashion_tags = ['fashion', 'outfit', 'clothes', 'menswear','wear']
# makeup_tags = ['makeup', 'eyeliner', 'bridal', 'shades', 'airbrush']
# beauty_tags = ['beauty', 'pimple', 'skin', 'oil', 'hair']
# lifestyle_tags = ['lifestyle', 'life', 'class', 'style', 'happy']
# luxury_tags = ['luxury', 'chic', 'handbag', 'stylish', 'brand']
# travel_tags = ['travel', 'world', 'destination', 'adventure', 'landscapes']
# photography_tags = ['photography', 'photo', 'editing', 'creative', 'artist']
# fitness_tags = ['fitness', 'nutrition', 'workout', 'healthy', 'exercise']
# sports_tags = ['sport', 'sports']
# gaming_tags = ['gaming', 'gamer', 'fun', 'games', 'stream']
# entertainment_tags = ['entertainment', 'movies', 'series', 'network', 'comedy']
# technology_tags = ['technology', 'tech', 'geek', 'smartphones', 'mobiles']
# investment_tags = ['investment', 'financial', 'stocks', 'market', 'trade']
# education_tags = ['education', 'lectures', 'competitive', 'exams', 'coaching']
# animal_tags = ['animal', 'habitat', 'wild', 'documentary', 'nature']
# health_tags = ['health', 'medical', 'prevent', 'treat', 'heal']
# self_improvement_tags = ['psychology', 'motivation', 'inspire', 'happiness', 'mind']

# %%
#Frame pre-processing function
def process(array,avoidwords):
    hashes = len(re.findall(r'[#,@]',str(array))) #counting hashtags
    text = re.sub(r'\[[0-9]*\]',' ',str(array))  #Remove Numbers
    text = re.sub("^\d+\s|\s\d+\s|\s\d+$", " ", text) # Remove nums
    text = re.sub(r'\s+',' ',text)  #Remove extra space
    text = re.sub(r"[^a-zA-Z0-9]+",' ',text)  #Remove special characters
    text = text.lower()  #Lower case all
    text = nltk.sent_tokenize(text)  #Tokenize to sentences 
    keywords = [nltk.word_tokenize(sentence) for sentence in text]
    raw_cap = len(keywords[0]) # Total number of words in caption
    stop_words = stopwords.words('english')
    stop_words.extend(avoidwords)
    for i in range(len(keywords)):
        keywords[i] = [word for word in keywords[i] if word not in stop_words]
    genuinity_percent = (raw_cap-hashes)*100/raw_cap
    return keywords,genuinity_percent


# normalize() -> given an array, converts to 1/0, top int(pos) will be 1
def normalize(keys, pos =3):  
    ax = [i for i in keys]
    temp = [i for i in keys]
    temp.sort()
    temp = temp[-pos:]
    for x in temp:
        ax[keys.index(x)] = 1
    for x in range(len(ax)):
        if ax[x] != 1:
            ax[x] = 0
    return ax

def normalizeSD(keys, thre =3):    # Given score array return shortlisted cats in given threshold
    if sum(keys) == 0:
        return keys
    ax = deviation(keys)
    ax = dev_shortlist(ax,thre)
    return ax
def deviation(array):
    mu = max(array)
    l = len(array)
    ar = []
    for x in range(l):
        ar.append(math.sqrt((array[x]-mu)**2)/l)
    total = sum(ar)
    for x in range(l):
        if total != 0:
            ar[x] = (ar[x]/total)*100
    return ar

def mean_deviation(array):
    l = len(array)
    mu = sum(array)/l
    ar = []
    for x in range(l):
        ar.append(math.sqrt((array[x]-mu)**2)/l)
    total = sum(ar)
    for x in range(l):
        if total != 0:
            ar[x] = (ar[x]/total)*100
    return ar

def dev_shortlist(dev_array,thre = 2):  # Shortlist using threshold from deviation array | return array in 1/0
    final_cat = [0]*len(dev_array)
    for i in range(len(dev_array)):
        if dev_array[i] <=thre:
            final_cat[i] = 1
    return final_cat
def compute1(caption,category,top =3):
    ar = []
    score = []

    # Code to get frequency distribution and unique keywords array
    keywords = []
    caption_freq = []
    counts = Counter(caption)
    if len(counts) > 0:
        labels, values = zip(*counts.items())
        ## sort your values in descending order
        indSort = np.argsort(values)[::-1]
        ## rearrange your data
        keywords = np.array(labels)[indSort]  # Label
        caption_freq = np.array(values)[indSort]  # Values
    
    # Detect words not in Google Dict | Put freq = 0
    for x in keywords:
        try:
            restConst = w.similarity(x,'something')
        except KeyError:
            caption_freq[np.where(keywords == x)] = 0
        
    #Google similaity function
    for x in category:
        empty = []
        for y in keywords:
            try:
                empty.append(w.similarity(x,y))
            except:
                empty.append(0)
        ar.append(empty)
    
    # Store the similarity values in dataframe
    frame = pd.DataFrame()
    frame = pd.DataFrame(ar, columns = keywords)
  
    #Normalize | top select
    for key in frame.columns:
        frame[key] = normalizeSD(frame[key].tolist(),top)
    
    # Multiply with frequency
    for row in range(len(frame)):
        frame.values[row] = [i*j for i,j in zip(frame.values[row],caption_freq)]
    # Sum the values => Score
    for row in range(len(frame)):
        score.append(sum(frame.values[row]))
    
    frame['category'] = category
    frame['Scores'] = score
    return frame,keywords[:20]

# compute() => category[] to be called outside
def compute2(caption,category_list,category,top =3):
    ar = []
    score = []

    # Code to get frequency distribution and unique keywords array
    keywords = []
    caption_freq = []
    counts = Counter(caption)
    if len(counts) > 0:
        labels, values = zip(*counts.items())
        ## sort your values in descending order
        indSort = np.argsort(values)[::-1]
        ## rearrange your data
        keywords = np.array(labels)[indSort]  # Label
        caption_freq = np.array(values)[indSort]  # Values
    
    # Detect words not in Google Dict | Put freq = 0
    for x in keywords:
        try:
            restConst = w.similarity(x,'something')
        except KeyError:
            caption_freq[np.where(keywords == x)] = 0
        
    #Google similaity function
    for c_tag in range(len(category_list)):
        empty1 = []
        for the_word in keywords:
            empty2 = []
            for k_tag in range(len(category_list[c_tag])):
                try:
                    empty2.append(w.similarity(category_list[c_tag][k_tag],the_word))
                except:
                    empty2.append(0)
            empty1.append(max(empty2))
        ar.append(empty1)
    # Store the similarity values in dataframe
    frame = pd.DataFrame()
    frame = pd.DataFrame(ar, columns = keywords)
  
    #Normalize | top select
    for key in frame.columns:
        frame[key] = normalizeSD(frame[key].tolist(),top)
    
    # Multiply with frequency
    for row in range(len(frame)):
        frame.values[row] = [i*j for i,j in zip(frame.values[row],caption_freq)]
    # Sum the values => Score
    for row in range(len(frame)):
        score.append(sum(frame.values[row]))
    
    frame['category'] = category
    frame['Scores'] = score
    return frame,keywords[:20]

def get_row_pscore(col_name,f1,i,f2,genuinity_score,top_keywords, scoreType):  # f1-mainframe | f2-frame
    ud = f1.loc[i,'id']
    ul = f1.loc[i,'url']
    row_in_array = [ud,ul]
    score_array = f2[scoreType].tolist()
    row_in_array.extend(score_array)
    row_in_array.append(genuinity_score)
    row_in_array.append(','.join(map(str,top_keywords)))
    zip_it = zip(col_name,row_in_array)
    convert_to_dict = dict(zip_it)
    return convert_to_dict

# %%
dfnew = pd.read_csv(r'E:\Winkl Mains\Task_4_Recategorisation\DATA\test_10_profiles.csv')
display(dfnew)
# Out:
#    Unnamed: 0      id                 handle                             name  \
# 0           0  122728     maa_bhukh_lagi_hai                              AT
# 1           1  122737           shuklaneerja                          Neerja
# 2           2  122784           thetriballux                       Naina Doi
# 3           3  122788     tellicherrykitchen             Tellicherry Kitchen
# 4           4  122798  gourmet_globe_trotter           Gourmet Globe Trotter
# 5           5  122800         bindass_jaipur                      जयपुर वाले
# 6           6  122809     sugarberryz_cakery              sugarberryz cakery
# 7           7  122837     padharo_mhare_desh  🔵केसरिया बालम पधारो म्हारे देश
# 8           8  122838             cheffed.in       Quick & easy food recipes
# 9           9  122859     food_stories_by_kj         Komal & Suresh Jaisingh
#
#                                                 url  gender country  \
# 0     https://www.instagram.com/maa_bhukh_lagi_hai/   Other   India
# 1           https://www.instagram.com/shuklaneerja/  Female   India
# 2           https://www.instagram.com/thetriballux/  Female   India
# 3     https://www.instagram.com/tellicherrykitchen/   Other   India
# 4  https://www.instagram.com/gourmet_globe_trotter/    Male   India
# 5         https://www.instagram.com/bindass_jaipur/   Other   India
# 6     https://www.instagram.com/sugarberryz_cakery/   Other   India
# 7     https://www.instagram.com/padharo_mhare_desh/   Other   India
# 8             https://www.instagram.com/cheffed.in/  Female   India
# 9     https://www.instagram.com/food_stories_by_kj/   Other   India
#
#                                             captions
# 0  ['भरवा बैंगन\nमसाला भरवा बैंगन और गरमा गरम ghe...
# 1  [None, None, 'If you are not able to make padm...
# 2  ['Like mom like daughter!!!', 'Kuch apni juban...
# 3  ['Thank you @iamjeevaa for visiting Tellicherr...
# 4  ['In Frame - Fried Chane with Poori and Chai(T...
# 5  ['.\nPc:@bhandsena\n📷\n📷\nUse tag |@bindass_ja...
# 6  ['Anniversary photo roll cake with gold drips\...
# 7  ['पाली (राजस्थान)।. यह है पाली के जाडन गांव स्...
# 8  ['Masala foxnuts\n.\n.\n.\nFor 15 minute recip...
# 9  ['💟\n. \n. \n#mumbaifoodtrendster #foodiefromb...

# %%
avoidwords = ['verified','none','follow','like']
corpus = dfnew.captions[2]
corpus,g_score = process(corpus,avoidwords)
corpus_array = corpus[0]
cp = ['self','spiritual','dress','car','speed','grow','hello']
aframe = pd.DataFrame()
aframe,keyss = compute2(cp,categories_list,categories)
per = aframe['Scores'].tolist()
per_sum = sum(per)
for x in range(len(per)):
    temp_number = (float)(per[x])
    per[x] = round((temp_number/per_sum)*100)
aframe['Percentage'] = per
display(aframe)
print(len(aframe))
# Out:
#     hello  grow  speed  car  dress  spiritual  self       category  Scores  \
# 0       0     0      0    0      0          0     0           food       0
# 1       1     0      0    1      1          0     0        fashion       3
# 2       0     0      0    0      1          0     0         makeup       1
# 3       0     0      0    0      0          0     0         beauty       0
# 4       1     0      0    0      0          0     1      lifestyle       2
# 5       0     0      0    1      0          0     0         luxury       1
# 6       0     0      0    0      0          0     0         travel       0
# 7       0     0      0    0      0          0     0    photography       0
# 8       0     0      1    0      0          0     1        fitness       2
# 9       0     0      1    1      0          0     0         sports       2
# 10      1     0      0    0      0          0     0         gaming       1
# 11      0     0      0    0      0          0     0  entertainment       0
# 12      0     1      1    0      0          0     0     technology       2
# 13      0     1      0    0      0          0     0     investment       1
# 14      0     0      0    0      0          0     0      education       0
# 15      0     0      0    0      0          0     0         animal       0
# 16      0     1      0    0      0          0     0         health       1
# 17      0     0      0    0      0          1     1    inspiration       2
#
#     Percentage
# 0            0
# 1           17
# 2            6
# 3            0
# 4           11
# 5            6
# 6            0
# 7            0
# 8           11
# 9           11
# 10           6
# 11           0
# 12          11
# 13           6
# 14           0
# 15           0
# 16           6
# 17          11
# 18

# %%
aframe = pd.DataFrame()
aframe,keyss = compute2(cp,categories)
per = aframe['Scores'].tolist()
per_sum = sum(per)
for x in range(len(per)):
    temp_number = (float)(per[x])
    per[x] = round((temp_number/per_sum)*100)
aframe['Percentage'] = per
display(aframe)
# Out:
#     spiritual  self       category  Scores  Percentage
# 0           0     0           food       0           0
# 1           0     1        fashion       1          11
# 2           0     0         makeup       0           0
# 3           1     0         beauty       1          11
# 4           1     1      lifestyle       2          22
# 5           0     0         luxury       0           0
# 6           0     0         travel       0           0
# 7           0     0    photography       0           0
# 8           1     1        fitness       2          22
# 9           0     0         sports       0           0
# 10          0     0         gaming       0           0
# 11          0     0  entertainment       0           0
# 12          0     0     technology       0           0
# 13          0     0     investment       0           0
# 14          1     0      education       1          11
# 15          0     1         animal       1          11
# 16          0     0         health       0           0
# 17          1     0    inspiration       1          11

# %%
profile_percentages =  pd.DataFrame(columns = col_name)
f1 = pd.DataFrame(columns = ['id','url'])
f1['id'] = [65783]
f1['url'] = ['http']
def get_row_pscore(col_name,f1,i,f2,genuinity_score,top_keywords, scoreType):  # f1-mainframe | f2-frame
    ud = f1.loc[i,'id']
    ul = f1.loc[i,'url']
    row_in_array = [ud,ul]
    score_array = f2[scoreType].tolist()
#     empty_score = [0]*(len(col_name)-len(score_array))
#     score_array.extend(empty_score)
    row_in_array.extend(score_array)
    row_in_array.append(genuinity_score)
    row_in_array.append(str([top_keywords]))
    zip_it = zip(col_name,row_in_array)
    convert_to_dict = dict(zip_it)
    return convert_to_dict
display(f1)
# display(aframe)
yy = get_row_pscore(col_name,f1,0,frame,genuinity_score,top_keywords.tolist(), 'Percentage')
profile_percentages = profile_percentages.append(yy,ignore_index=True)
print(yy)
display(profile_percentages)
# Out:
#       id   url
# 0  65783  http
# {'user_id': 65783, 'url': 'http', 'Food': 42, 'Fashion': 1, 'Makeup': 1, 'Beauty': 3, 'Lifestyle': 5, 'Luxury': 14, 'Travel': 0, 'Photography': 2, 'Fitness': 3, 'Sports': 2, 'Gaming': 2, 'Entertainment': 3, 'Gadgets & Tech': 6, 'Finance': 3, 'Education': 2, 'Animal/Pet': 0, 'Health': 1, 'Self Improvement': 2, 'Art': 1, 'Parenting': 1, 'Books': 6, 'genuinity_score': 33.66054775694513, 'top keywords': "[['homemade', 'foodies', 'rice', 'salad', 'roti', 'taste', 'made', 'food', 'one', 'puri', 'good', 'chutney', 'kadi', 'masala', 'day', 'best', 'try', 'happy', 'fav', 'home']]"}
#   user_id   url Food Fashion Makeup Beauty Lifestyle Luxury Travel  \
# 0   65783  http   42       1      1      3         5     14      0
#
#   Photography  ... Finance Education Animal/Pet Health Self Improvement Art  \
# 0           2  ...       3         2          0      1                2   1
#
#   Parenting Books genuinity_score  \
# 0         1     6       33.660548
#
#                                         top keywords
# 0  [['homemade', 'foodies', 'rice', 'salad', 'rot...
#
# [1 rows x 25 columns]

# %% [markdown]
# ## Testing new compute()

# %%
dfnew = pd.read_csv(r'E:\Winkl Mains\Task_4_Recategorisation\DATA\RandomInfluencers.csv')
# dfnew = dfnew[15:20]
display(dfnew)
# Out:
#         id                      handle                             name  \
# 0   210026           bhavinkaklotar_26                 Bhavin kaklotar
# 1   210028             dailykritisanon                  Kriti Sanon 🇬🇧
# 2   210042           rameshwari__dassi                 Rameshwari Sahu
# 3   210043                 darshan_.57               Darshan Tarsariya
# 4   210049            deepveerkeralafp        👑DEEPVEER👑 | FAN ACCOUNT
# 5   250001                akhil_emoboy                     AkHil eMoboy
# 6   250022               arushipatkeyy    Arushi patkey|Content Creator
# 7   250029         thatbloggernextdoor                       Esha Wasey
# 8   250040            himadri.official                          HIMADRI
# 9   250043                   yasqueer_                        Avantika⚡
# 10  190018             kartik_bagrecha                     K A R T I K
# 11  190029                kudla_models                    kudla models
# 12  190078                bigcatsindia                        Big Cats
# 13  190081      vaibhavregephotography                    Vaibhav Rege
# 14  190091       karansidhuphotography                     Karan Sidhu
# 15  180007             pollachipapyrus                Pollachi Papyrus
# 16  180022                cosmicstills                    Jayant Batra
# 17  180060                 mandal_neha           N E H A   M A N D A L
# 18  180117              photoquipindia                 Photoquip India
# 19  180118  ashnoorkaur_princess_tanya                 ♛Ashnoor kaur ♛
# 20  150005            pashionfashion__                  Indian Fashion
# 21  150008      syscotech_it_solution_           SyscoTech IT Solution
# 22  150019            anil.parmar.2434                  ANIL R PARMAR 🔵
# 23  150022                mystickerala                   MysticKerala™
# 24  150044                  the_fabcan           Harshita | the_fabcan
# 25  110003                 dilse_delhi                     DilSe Delhi
# 26  110004               wassup_bhopal              Wassup Bhopal ● WB
# 27  110006                urstylecoach                    UrStyleCoach
# 28  110016        thedrunkenb_official            The Drunken Botanist
# 29  110051            idivyeshtalaviya                Divyesh Talaviya
# 30   90002       photo_addiction_india            Photo Addiction®️ 🇮🇳
# 31   90011              styliaa_studio  STYLIAA ™ " The Style Studio "
# 32   90015               nitinbaranwal                             ni३
# 33   90024               decorbytheway                Decor By The Way
# 34   90031                  azeem.ajju          🇦 🇿 🇪 🇪 🇲      🇦 🇯 🇯 🇺
# 35   75011               gethighonfood                   Nitish Mathur
# 36   75034                eatoutmumbai                   EatOut Mumbai
# 37   75037               cameracuisine    Jai K Puri | Camera Cuisine™
# 38   75059            sushma.maheshwar              sushma.maheshwar 🇮🇳
# 39   75078       rupanjanabhattcharjee         Rupanjana Bhattcharjee👑
# 40   55007                   saaaaaheb              SAAHEB S. || 009 🔹
# 41   55008       theoberoigrandkolkata        The Oberoi Grand Kolkata
# 42   55009              themotographer                     MotoGrapher
# 43   55026                fabricshub07                      Fabricshub
# 44   55033           guptascelebration             Gupta's Celebration
# 45   25002               krishitasheth                  Krishita Sheth
# 46   25013                foodswaggers                   Food Swaggers
# 47   25024           rudritachatterjee              Rudrita Chatterjee
# 48   25029              gastronautsden                Gastronauts' Den
# 49   25034                 sejalmjoshi         Foodie sejal jani joshi
#
#                                                   url  gender country  \
# 0       https://www.instagram.com//bhavinkaklotar_26/    Male   India
# 1         https://www.instagram.com//dailykritisanon/   Other   India
# 2       https://www.instagram.com//rameshwari__dassi/  Female   India
# 3             https://www.instagram.com//darshan_.57/    Male   India
# 4        https://www.instagram.com//deepveerkeralafp/   Other   India
# 5              https://www.instagram.com/akhil_emoboy    Male   India
# 6             https://www.instagram.com/arushipatkeyy  Female   India
# 7       https://www.instagram.com/thatbloggernextdoor  Female   India
# 8          https://www.instagram.com/himadri.official  Female   India
# 9                 https://www.instagram.com/yasqueer_  Female   India
# 10         https://www.instagram.com/kartik_bagrecha/    Male   India
# 11            https://www.instagram.com/kudla_models/   Other   India
# 12            https://www.instagram.com/bigcatsindia/   Other   India
# 13  https://www.instagram.com/vaibhavregephotography/    Male   India
# 14   https://www.instagram.com/karansidhuphotography/    Male   India
# 15         https://www.instagram.com/pollachipapyrus/   Other   India
# 16            https://www.instagram.com/cosmicstills/    Male   India
# 17             https://www.instagram.com/mandal_neha/  Female   India
# 18          https://www.instagram.com/photoquipindia/   Other   India
# 19  https://www.instagram.com/ashnoorkaur_princess...  Female   India
# 20        https://www.instagram.com/pashionfashion__/   Other   India
# 21  https://www.instagram.com/syscotech_it_solution_/   Other   India
# 22        https://www.instagram.com/anil.parmar.2434/    Male   India
# 23            https://www.instagram.com/mystickerala/   Other   India
# 24              https://www.instagram.com/the_fabcan/  Female   India
# 25             https://www.instagram.com/dilse_delhi/    Male   India
# 26           https://www.instagram.com/wassup_bhopal/   Other   India
# 27            https://www.instagram.com/urstylecoach/   Other   India
# 28    https://www.instagram.com/thedrunkenb_official/    Male   India
# 29        https://www.instagram.com/idivyeshtalaviya/    Male   India
# 30   https://www.instagram.com/photo_addiction_india/   Other   India
# 31          https://www.instagram.com/styliaa_studio/   Other   India
# 32           https://www.instagram.com/nitinbaranwal/   Other   India
# 33           https://www.instagram.com/decorbytheway/   Other   India
# 34              https://www.instagram.com/azeem.ajju/    Male   India
# 35           https://www.instagram.com/gethighonfood/    Male   India
# 36            https://www.instagram.com/eatoutmumbai/   Other   India
# 37           https://www.instagram.com/cameracuisine/    Male   India
# 38        https://www.instagram.com/sushma.maheshwar/  Female   India
# 39   https://www.instagram.com/rupanjanabhattcharjee/  Female   India
# 40               https://www.instagram.com/saaaaaheb/    Male   India
# 41   https://www.instagram.com/theoberoigrandkolkata/   Other   India
# 42          https://www.instagram.com/themotographer/   Other   India
# 43            https://www.instagram.com/fabricshub07/   Other   India
# 44       https://www.instagram.com/guptascelebration/   Other   India
# 45           https://www.instagram.com/krishitasheth/  Female   India
# 46            https://www.instagram.com/foodswaggers/   Other   India
# 47       https://www.instagram.com/rudritachatterjee/  Female   India
# 48          https://www.instagram.com/gastronautsden/   Other   India
# 49             https://www.instagram.com/sejalmjoshi/  Female   India
#
#                                              captions  \
# 0   ['😍😍😍\n.\n#vitmedia\xa0#portrait\xa0#portraito...
# 1   ["know your worth never settle for less 😎 // #...
# 2   ['This festival bring home the most valuable b...
# 3   ['#jikadarabhavin .#fashionindia #portraitoffi...
# 4   ['💜✨', 'His heart eyes for her😍💓✨', 'Happy the...
# 5   ['Angine palathum paraym emolyf💝💝#emo #keralag...
# 6   ["🎅🏻MEGA Xmas GIVEAWAY!🎅🏻\nMerry spirits flow ...
# 7   ['Winters are here so is my new skincare routi...
# 8   ['🍁', '❄️', 'Winging it since forever♾✨ \n#sel...
# 9   ['🐶', '👉👈', 'Real Thug With Real Pug.', 'Miff ...
# 10  ["The reason birds can fly and we can't is sim...
# 11  ['In frame:- @manas.knj', '', 'Happy navaratri...
# 12  ['A face that knows it’s fighting a Daily Thre...
# 13  ['Portraits Shots from my recent Studio Lighti...
# 14  ['Huma & Atif (Day 2)\n.\nBreathtakingly gorge...
# 15  ['Hello weekend! 🤩 RePosted from @aerial_holic...
# 16  ['Shot For : @champalaljewellers_rajeshmodi \n...
# 17  ['MEIN APNI FAVOURITE HOON...\n\n(When Light i...
# 18  ['Food Photographer @sid_uzumaki beautifully c...
# 19  ['yes.. i fell in love with you🍯 🥰. Idk how.. ...
# 20  ['Aditya Narayan, Shweta Agarwal wedding recep...
# 21  ['Happy holi \nSyscotech IT Solution \n#holi #...
# 22  ['#dahodcity #dahodian #suratphotoclub #mumbai...
# 23  ['Kolukkumalai Munnar 🍃Follow @mystickerala🔽🔽_...
# 24  ['The nature brings true happiness to us.. \n....
# 25  ['Sarojni Nagar is open now. \n.\n.\n.\nJaan s...
# 26  ['Hello everyone we are excited to invite you ...
# 27  ['Power dressing means looking ahead, knowing ...
# 28  ['You’re about to walk into the greatest seaso...
# 29  ['Roses are red, white, pink and yellow, and g...
# 30  ['Photo Credit - @cam.alive\n\nLet us remember...
# 31  ['Swipe left for more collection\n\n#EUR € 53 ...
# 32  ['🔒 mysterious world 🔓.\nStyled in @_huemn . ....
# 33  ['This tray is perfect for decorating ottomans...
# 34  ['#shotoniphone \n.\n@nabb_uu 🏍️\n@_mr.aa7\n.\...
# 35  ['Lassi Malai Marke !!! Memories when I was in...
# 36  ['One Dish that we have really missed during t...
# 37  ['Le Kitchen Express @lekitchen_catering\nHas ...
# 38  ["***ನಿಂಬೆಹಣ್ಣಿನ ತಿಳಿ ಸಾರು /Lemon Rasam**** on...
# 39  ['“For we women are not only the deities of th...
# 40  ['Life is ten percent what happens to Us & nin...
# 41  ["Get set to celebrate your date with Thailand...
# 42  ['[SWIPE LEFT] Off bike style for the #ninjaH2...
# 43  ['Georgette enb zari \nWidth-44\nPrice-₹550/mt...
# 44  ['ARE YOUR SPIDEY SENSES TINGLING?\nSwing into...
# 45  ['There are friends, there is family and then ...
# 46  ['Thousands laid down their lives so that our ...
# 47  ['No Oil Easy Healthy Chicken. Full recipe in ...
# 48  ["In the frame - Pizza Omelette\n\nPrice - INR...
# 49  ['Desi food :- bhakhri , potato peas tometo sa...
#
#                                                   bio
# 0                                                Mom💓
# 1   slaying since 1990 ∞ her middle name is "prett...
# 2   🙏🙏YoU aRe AmAzing😍 \n💞😘बन्दीछोड़ 😍💞\nBindass gi...
# 3   🖤son of prajapati 🤴\n🖤 single boy 💗\n🖤I believ...
# 4   Welcome to the world of Deepveer💑👑\nDP mention...
# 5   👉Paid promotion only 👈Modeling 💓ex tiktoker🎸🎸m...
# 6   Stop making sense .Logic is predictable.\n THI...
# 7   Hyd, India\n✉️ esha.tbnd@gmail.com\nFounder: @...
# 8   Life’s too short to maintain an aesthetic feed...
# 9   🏳️‍🌈\nFollow my bairn @sonofabitch55\n📍MFP | BBSR
# 10                                    Unpredictable 🔮
# 11  ☝Follow this page \n📥DM ur HD pics/Dubs/videos...
# 12  A wildlife blog for #wildlife lovers of the wo...
# 13  #commercialphotographer #fashionphotographer #...
# 14  Award Winning Wedding Photographer and Filmmak...
# 15  Documenting the rich bio-cultural diversity of...
# 16  Luxury wedding& commercial Photography & Films...
# 17  ACTOR I MODEL I CHOREOGRAPHER\nFOUNDER @kalane...
# 18  Pioneer in photography lighting equipment in I...
# 19  ❥Ye Sirf Star Nhi Duniya H Meri🌎\nTujhse Suru ...
# 20  B R I D E L\nYour daily dose of wedding inspir...
# 21  To Get latest updates on \n | Websitedesign | ...
# 22  😈 Name :- Kisko Maalum\n😕 Age:- Shaddi Karega\...
# 23  ▶ Universal Photo Hub\n▶ More About God's Own ...
# 24  Affordable fashion content \n📹- #youtuber - 11...
# 25            Food | Travel | Life\nGurgaon & Delhi 🐾
# 26  • Proud Bhopali\n• Winner MP STATE TOURISM AWA...
# 27  •Fashion Styling/Consultations\n•Styling works...
# 28  The Adventures of the Drunken Botanist, the Wh...
# 29  •Model📸\n•Celebrity Fashion Stylist\n•Editoria...
# 30  ⤴️Hashtag us at #photoaddiction_india\n⤴️DM/TA...
# 31  From #Anarkali suits to Bespoke\n🌍| Delivering...
# 32  An earthling beyond #gender & social discrimin...
# 33  By- @prachi.malewar 🙋‍♀️\nCreator of custom wo...
# 34  • EXPLORE• TRAVEL • PHOTOGRAPHY•  \n.\nEyes be...
# 35  FOOD blogger turned MARKETER, helping fortune ...
# 36  Discovering & Picking the Best of food from ar...
# 37  Photographer\nRecipe Developer\nBudding Chef \...
# 38  𝑳𝒂𝒘𝒚𝒆𝒓| #ƑօօժҍӀօցցҽɾ @𝒉𝒕𝒕𝒑𝒔://𝑲𝒉𝒂𝒂𝒅𝒚𝒂𝒂.𝒏𝒆𝒕\nℜ𝔢...
# 39  Dm for collaboration/pr❤\nMail- raksha27bardia...
# 40  BENGALI  INDIAN. 😎\n📍Alipurduar || Kolkata\n♍\...
# 41                                                NaN
# 42  Living Life like a Video Game . 60+ countries....
# 43  🌺We deal in retail and wholesale of beautiful ...
# 44  Dreamy events brilliantly conceptualised\n& ex...
# 45  Lifestyle, Travel & Fashion curated by yours t...
# 46  Swagging our food 😎🤘\n👫|Priyanka Singhal|Tusha...
# 47  Fashion | Lifestyle | Beauty | Travel\nE-Mail ...
# 48  Good food, good life!\nBangalore foodies | Dee...
# 49  ▪vegeterian-foodie\n▪pakki gujaratan❤\n▪Ahmeda...

# %%
x = requests.get('http://44.229.68.155/insta_users/get_uncategorized_accounts?limit=20&current_id=136587', headers={'Authorization': 'Token ruor7REQi9KJz6wIQKDXvwtt'})
status = x.status_code
data = x.json()
df = pd.DataFrame(data['users'])
dfnew = pd.DataFrame()
dfnew = pd.DataFrame(columns=['id','handle','name','url','gender','country','captions','bio'], data = df[['id','handle','name','url','gender','country','captions','bio']].values)
display(dfnew)
caps = dfnew.captions.iloc[0]
print(type(caps))
print(len(caps))
# print(caps)
# Out:
#         id                  handle                             name  \
# 0   136599  divyankatripathidahiya        Divyanka Tripathi Dahiya
# 1   136621             varunverrma                     Varun Verma
# 2   136625       mekahairandmakeup         MEKA HAIR AND MAKEUP 🇦🇺
# 3   136629     happywedding.lifeen            happywedding.life en
# 4   136665             jasminhope_                          JASMIN
# 5   136684            bikewithgirl                Priyanka Kochhar
# 6   136689        nashi_cappuccino                           Nashi
# 7   136692               oursindia                       Oursindia
# 8   136697  navaneeth_unnikrishnan          Navaneeth Unnikrishnan
# 9   136701             shafilegacy                    shafi legacy
# 10  136716             rehanponcha                    Rehan Poncha
# 11  136722               alokabhay                      Abhay Alok
# 12  136733           kritisanon_ig                           Kriti
# 13  136737         pistoleindustry                         Pistole
# 14  136743            gewelsbymona       Gewels: Experience Luxury
# 15  136746          rajputgauri981                    Rajput Gauri
# 16  136752                suraj.ps                        Suraj PS
# 17  136770        the.travel.freak             Asmita Bhattacharya
# 18  136774              zinklondon                     ZINK LONDON
# 19  136786               samanl33t  SaMaN-Travel,Adventure,InfoSec
#
#                                                   url  gender country  \
# 0   https://www.instagram.com/divyankatripathidahiya/  Female   India
# 1              https://www.instagram.com/varunverrma/    Male   India
# 2        https://www.instagram.com/mekahairandmakeup/  Female   India
# 3      https://www.instagram.com/happywedding.lifeen/   Other   India
# 4              https://www.instagram.com/jasminhope_/  Female   India
# 5             https://www.instagram.com/bikewithgirl/  Female   India
# 6         https://www.instagram.com/nashi_cappuccino/    Male   India
# 7                https://www.instagram.com/oursindia/   Other   India
# 8   https://www.instagram.com/navaneeth_unnikrishnan/    Male   India
# 9              https://www.instagram.com/shafilegacy/    Male   India
# 10             https://www.instagram.com/rehanponcha/    Male   India
# 11               https://www.instagram.com/alokabhay/    Male   India
# 12           https://www.instagram.com/kritisanon_ig/   Other   India
# 13         https://www.instagram.com/pistoleindustry/   Other   India
# 14            https://www.instagram.com/gewelsbymona/   Other   India
# 15          https://www.instagram.com/rajputgauri981/  Female   India
# 16                https://www.instagram.com/suraj.ps/    Male   India
# 17        https://www.instagram.com/the.travel.freak/  Female   India
# 18              https://www.instagram.com/zinklondon/   Other   India
# 19               https://www.instagram.com/samanl33t/    Male   India
#
#                                              captions  \
# 0   [#Welcome2021, Thanks for dragging me out of t...
# 1   [I'm staying #Harpalfashionable with @amazonfa...
# 2   [, Hair by #mekahairandmakeup \n#curleyhair #c...
# 3   ["We keep this love in a photograph"❤️❤️😍😍📷 .....
# 4   [#ad Rocking around the Christmas tree with my...
# 5   [Spa Day with the brother @yomody be like...🧼🛁...
# 6   [ഒറ്റക്കൊമ്പൻ 🐘 😁#komban #shootonphone #elepha...
# 7   [The Tale of the Mountains !..________________...
# 8   [Filtered Sun, Munnar, Kerala - The game of li...
# 9   [#throwback #ride #life #calm #feel #mood #min...
# 10  [So much of my life and work has been inspired...
# 11  [Raksha Bandhan is the celebration of the love...
# 12  [😍🔥\n\n..\n.\n.\n.\n. .\n., 🤫💕, 💝😘\n.., Beauti...
# 13  [Come join the Pistole Army! The only rule is ...
# 14  [Dakshinaya Statement Earrings ✨\n.\n.\nTo Inq...
# 15  [#selflove #love #selfcare #loveyourself #moti...
# 16  [For those who talk shit behind 😂🖕🏻❤️ #pooveun...
# 17  [We open our eyes every morning.\n\nBut do we ...
# 18  [Sway in the misty breeze and be seen in the M...
# 19  [Mountains & I ...\n.\n.\n.\n.\n.\n.\n.\n\n#mo...
#
#                                                   bio
# 0                                           An Artist
# 1   Fashion | lifestyle | travel\nMr India suprana...
# 2   BRIDAL | NON BRIDAL | HAIR/MAKEUP | SAREE DRAP...
# 3   Happy Wedding.life is the Wedding Portal to fi...
# 4   #Beauty. #Fashion. Home #blogger 💫🎄\nMy shop -...
# 5   Just a girl that loves motorcycles and fast ca...
# 6   Founder @cappuccino_creatives  \n     📽 FILMER...
# 7                          Use - #oursindia Or #b_ind
# 8   Fragments of my Imagination\nAmbassador @sonya...
# 9           𝙸 𝚆𝙰𝚂 𝙱𝙾𝚁𝙽 𝚃𝙾 𝙱𝙴 𝚁𝙴𝙰𝙻 𝙽𝙾𝚃 𝚃𝙾 𝙱𝙴 𝙿𝙴𝚁𝙵𝙴𝙲𝚃 🤘
# 10  Olympian|Arjuna Awardee|Pro Swimmer Motivation...
# 11  •Men's wear •Grooming •Fitness \nContent Creat...
# 12  👗Fashion👚\n💄Beauty 💄\n👰Style 👸\n❣@kritisanon ❣...
# 13                           What are you hungry for?
# 14  BRIDAL I PRET I BESPOKE (custom made) \nRevamp...
# 15  Actress, Model and influencer.. \nDM for colla...
# 16  Be humble 🥰\nAKA Kesavan in #pooveunakkaga #su...
# 17  ✈️ Solo Traveller\n🎒 Backpacker\n🧗 Trekker\n🎓 ...
# 18  Don't try to fit in, find something to stand o...
# 19  - Soul\n- Explorer\n- Stunt Rider\n- Scuba, Sk...
# <class 'list'>
# 289

# %%
categories = ['food', 'fashion', 'makeup', 'beauty', 'lifestyle','luxury', 'travel','photography','fitness','sports','gaming', 'entertainment', 'technology','investment','education', 'animal', 'health', 'inspiration','art','parenting','book']
categories_list = [['food', 'recipe', 'cooking'],
              ['fashion', 'outfit', 'clothes'],
              ['makeup','shades','haircare','face'],
              ['beauty','skin', 'oil', 'hair'],
              ['lifestyle','style'],
              ['luxury','rich','billionaire','car'],
              ['travel', 'world', 'destination', 'adventures', 'landscapes','bucket'],
              ['photography', 'photo', 'editing'],
              ['fitness', 'nutrition', 'workout', 'healthy', 'exercise','run'],
              ['sport', 'sports','win','loss'],
              ['gaming','stream','freefire','pubg'],
              ['entertainment', 'movies', 'series', 'film', 'comedy','actor','actress'],
              ['technology', 'tech', 'geek', 'smartphones', 'mobiles'],
              ['investment', 'financial', 'stocks', 'market', 'trade'],
              ['education', 'lectures', 'competitive', 'exams', 'coaching'],
              ['animal', 'wild', 'wildlife', 'nature','pet'],
              ['health', 'medical', 'prevention','cure', 'treatment', 'heal'],
              ['psychology', 'motivation', 'inspiration', 'mind','spiritual'],
              ['sketch','DIY','painting','art','drawing'],
              ['children','kids','infant','family','parenting','toys'],
              ['books','review','journaling','stationery','study']]
col_name = ['user_id','url','Food','Fashion', 'Makeup', 'Beauty', 'Lifestyle','Luxury', 'Travel','Photography','Fitness','Sports','Gaming', 'Entertainment', 'Gadgets & Tech','Finance','Education', 'Animal/Pet', 'Health', 'Self Improvement','Art', 'Parenting', 'Books', 'genuinity_score','top keywords']
API_categories = ['Food','Fashion', 'Makeup', 'Beauty', 'Lifestyle','Luxury', 'Travel','Photography','Fitness','Sports','Gaming', 'Entertainment', 'Gadgets & Tech','Finance','Education', 'Animal/Pet', 'Health','Self Improvement','Art', 'Parenting', 'Books']

# %%
profile_percentages =  pd.DataFrame(columns = col_name)
idsdone =0
for i in range(len(dfnew)):

    try:
        #Store userid | caption | total posts
        userid = dfnew['id'].iloc[i]
        captions = dfnew['captions'].iloc[i]
        bio = dfnew['bio'].iloc[i]
        total_posts = len(captions)

        # Words which mostly occurs in insta post and we want to avoid considering them for the sake of accuracy of results
        avoidwords = ['verified','none','follow','like','reposted','influencer','gmail','com','collabs','collaboration']

        #Converting to keywords
        captions,genuinity_score = process(captions,avoidwords)
        caption_array = captions[0]
        bio,ignore_this_var = process(bio,avoidwords)
        bio_array = bio[0]
        # Punishing accounts which has less than 3 words in caption
        print(len(caption_array),5*(total_posts))
        if len(caption_array) < 5*(total_posts):
            raise Exception("Too less words for categorization")

        #Temporary array i-> interim
        icaption_array = [z for z in caption_array]
        ibio_array = [z for z in bio_array]
        # Removing words not in dictionary also single characters
        discarded_words = []
        discarded_bio_words = []
        for x in caption_array:
            try:
                checkword = w.similarity(x,'something') #Check word if exist in googlenews
                if len(x) <=2: #Removing single character
                    icaption_array.pop(icaption_array.index(x))
            except KeyError:
                discarded_words.append(icaption_array.pop(icaption_array.index(x)))
        for x in bio_array:
            try:
                checkword = w.similarity(x,'something') #Check word if exist in googlenews
                if len(x) <=2: #Removing single character
                    ibio_array.pop(ibio_array.index(x))
            except KeyError:
                discarded_bio_words.append(ibio_array.pop(ibio_array.index(x)))
        #Restore Array
        caption_array = [z for z in icaption_array]
        bio_array = [z for z in ibio_array]
        # Check similarity in discarded words
        discard_word_scores = [0]*len(categories)
        discard_bio_word_scores = [0]*len(categories)
        for x_word in discarded_words:
            for category_index in range(len(categories_list)):
                for the_category in categories_list[category_index]:
                    if the_category in x_word:
                        discard_word_scores[category_index] = 1 + discard_word_scores[category_index]
        for x_word in discarded_bio_words:
            for category_index in range(len(categories_list)):
                for the_category in categories_list[category_index]:
                    if the_category in x_word:
                        discard_bio_word_scores[category_index] = 1 + discard_bio_word_scores[category_index]           
        if len(caption_array) ==0:
            raise Exception("No Words in profile for categorization or Different language")

        # Word2vec computation
        frame = pd.DataFrame()
        frame, top_keywords = compute2(caption_array,categories_list,categories,3) ##############
        # Word2vec for bio
        frame_bio = pd.DataFrame()
#         frame_bio,ignore_keywords = compute2(bio_array,categories_list,categories,2) ###################
#         # Storing bio scores
#         bio_score = frame_bio['Scores'].tolist()
        # Compute() for bio corpus
        bio_score = [0]*len(categories)
        for x_word in bio_array:
            for category_index in range(len(categories_list)):
                for the_category in categories_list[category_index]:
                    if the_category in x_word:
                        bio_score[category_index] = 1 + bio_score[category_index]
    
        for sc in range(len(bio_score)):
            bio_score[sc] = bio_score[sc] + discard_bio_word_scores[sc] 

        # Add up computed score with discarded score
        score_column = frame['Scores'].tolist()
        for ind in range(len(score_column)):
            score_column[ind] = score_column[ind] + discard_word_scores[ind]

        # Add weighted score of bio in main score
        normalize_bio_score = normalizeSD(bio_score,3)
#         print("bio score: ",bio_score)
#         print("bio norm: ",normalize_bio_score)
        for sc in range(len(normalize_bio_score)):
            if normalize_bio_score[sc] == 1:
                score_column[sc] = score_column[sc]*2
        frame['Scores'] = score_column

        #Convert to Percentage
        per = frame['Scores'].tolist()
        per_sum = sum(per)
        for x in range(len(per)):
            temp_number = (float)(per[x])
            per[x] = round((temp_number/per_sum)*100)
        frame['Percentage'] = per


        #Store profile percentage
        row_df_5 = get_row_pscore(col_name,dfnew,i,frame,genuinity_score,top_keywords.tolist(),'Percentage')
        profile_percentages = profile_percentages.append(row_df_5,ignore_index=True)

        # POST API Request
#                 file = to_dict_api(frame['Percentage'].tolist(),API_categories,top_keywords,dfnew,i)
#             url = 'http://44.229.68.155/insta_user/add_category_to_insta_user'
#             y = requests.post(url, data = file,headers={'Authorization': 'Token ruor7REQi9KJz6wIQKDXvwtt'})

#             if y.status_code !=200:
#                 raise Exception("Post request error {}".format(y.status_code))

        print("ID no. {} Done! Total {} ids done".format(userid,idsdone))
        idsdone = idsdone +1
        
    except Exception as Argument:
        # creating/opening a file 
        f = open(r"E:\Winkl Mains\Task_4_Recategorisation\DATA\errorfile.txt", "a") 
        # writing in the file 
        f.write("Userid\t"+str(userid)+"\t: "+str(Argument)+str("\n")) 
        # closing the file 
        f.close()
        

display(profile_percentages)
profile_percentages.to_csv(r"E:\Winkl Mains\Task_4_Recategorisation\DATA\Random_account_improve4.csv")
# Out:
# 3757 1445
# ID no. 136599 Done! Total 0 ids done
# 4949 1695
# ID no. 136621 Done! Total 1 ids done
# 3574 755
# ID no. 136625 Done! Total 2 ids done
# 5006 540
# ID no. 136629 Done! Total 3 ids done
# 5459 1050
# ID no. 136665 Done! Total 4 ids done
# 12782 1580
# ID no. 136684 Done! Total 5 ids done
# 1433 740
# ID no. 136689 Done! Total 6 ids done
# 6192 540
# ID no. 136692 Done! Total 7 ids done
# 7794 1200
# ID no. 136697 Done! Total 8 ids done
# 8512 1460
# ID no. 136716 Done! Total 9 ids done
# 9801 980
# ID no. 136722 Done! Total 10 ids done
# 5998 1380
# ID no. 136733 Done! Total 11 ids done
# 1538 545
# ID no. 136737 Done! Total 12 ids done
# 10317 1560
# ID no. 136743 Done! Total 13 ids done
# 7486 1325
# ID no. 136746 Done! Total 14 ids done
# 6104 1260
# ID no. 136752 Done! Total 15 ids done
# 9116 985
# ID no. 136770 Done! Total 16 ids done
# 12155 1310
# ID no. 136774 Done! Total 17 ids done
# 2812 810
# ID no. 136786 Done! Total 18 ids done
#    user_id                                                url Food Fashion  \
# 0   136599  https://www.instagram.com/divyankatripathidahiya/    2       3
# 1   136621             https://www.instagram.com/varunverrma/    2       8
# 2   136625       https://www.instagram.com/mekahairandmakeup/    1       6
# 3   136629     https://www.instagram.com/happywedding.lifeen/    3       5
# 4   136665             https://www.instagram.com/jasminhope_/    3       8
# 5   136684            https://www.instagram.com/bikewithgirl/    1       3
# 6   136689        https://www.instagram.com/nashi_cappuccino/    2       4
# 7   136692               https://www.instagram.com/oursindia/    1       2
# 8   136697  https://www.instagram.com/navaneeth_unnikrishnan/    1       2
# 9   136716             https://www.instagram.com/rehanponcha/    2       2
# 10  136722               https://www.instagram.com/alokabhay/    2      12
# 11  136733           https://www.instagram.com/kritisanon_ig/    1      10
# 12  136737         https://www.instagram.com/pistoleindustry/    2       4
# 13  136743            https://www.instagram.com/gewelsbymona/    2       8
# 14  136746          https://www.instagram.com/rajputgauri981/    2       7
# 15  136752                https://www.instagram.com/suraj.ps/    2       4
# 16  136770        https://www.instagram.com/the.travel.freak/    2       2
# 17  136774              https://www.instagram.com/zinklondon/    3      10
# 18  136786               https://www.instagram.com/samanl33t/    1       1
#
#    Makeup Beauty Lifestyle Luxury Travel Photography  ... Finance Education  \
# 0       6      5         3      4      7           2  ...       2         4
# 1       5      3         6      3     12           3  ...       2         4
# 2      28     24         3      1      6           3  ...       0         1
# 3       4      6         5      2     21           2  ...       4         2
# 4       6     11         3      4      6           1  ...       2         3
# 5       4      3         3     15      6           2  ...       1         3
# 6       4      4         3      5      7           3  ...       1         4
# 7       3      3         2      3     12          14  ...       2         3
# 8       6      5         3      5     13           5  ...       2         3
# 9       4      3         3      3     14           1  ...       2         4
# 10      5      5         5      3      5           3  ...       2         3
# 11      7     13         7      3      7           4  ...       1         2
# 12      5      3         3      4      8           3  ...       2         4
# 13      7      7         5      5      9           2  ...       2         2
# 14      4      6         4      3      7           5  ...       2         2
# 15      4      5         2      3      8           3  ...       2         2
# 16      5      2         2      3     26           2  ...       2         3
# 17      6      5        13      5      8           2  ...       2         2
# 18      4      5         3      4     23           4  ...       1         2
#
#    Animal/Pet Health Self Improvement Art Parenting Books genuinity_score  \
# 0           4      5               10   7         7     4       81.241851
# 1           3      3                7   4         6     4       77.982795
# 2           1      1                3   6         3     3       16.900676
# 3           3      2                6   5         9     6       43.448150
# 4           4      4                7   4         7     5       80.485175
# 5           4      3                7   4         7     3       62.017341
# 6           4      2                7   4         6     4       40.608543
# 7           4      2                6   7         5     5       64.945557
# 8           7      3                6   6         4     4       72.018266
# 9           3      4               16   4         6     3       86.894900
# 10          3      4                8   3         6     4       65.488027
# 11          2      3                7   5         4     4       51.631702
# 12          3      4                9   6         8     5       78.842234
# 13          4      3                5   6         6     7       69.959965
# 14          2      3                6   4         6     4       26.440329
# 15          4      2                8   5         9     3       44.798725
# 16          5      4                9   3         6     3       66.937966
# 17          3      2                3   7         4     6       50.708101
# 18          6      3                9   5         6     4       46.861472
#
#                                          top keywords
# 0   love,life,one,beautiful,best,hair,women,outfit...
# 1   photography,fashion,link,get,day,love,bio,indi...
# 2   makeup,hair,beautiful,mua,saree,melbourne,phot...
# 3   wedding,life,image,https,credit,get,inspired,w...
# 4   new,love,get,perfect,christmas,dress,gifted,al...
# 5   bikes,motorcycle,india,superbike,bike,racing,b...
# 6   cappuccino,polo,part,day,creatives,kerala,irfa...
# 7   artist,india,pictures,videos,gallery,get,shari...
# 8   shot,landscape,travel,photography,image,icelan...
# 9   love,fitness,one,time,sport,travel,watch,golf,...
# 10  fashion,love,style,link,bio,life,check,photogr...
# 11  repost,hair,kriti,styled,bollywood,make,outfit...
# 12  shot,get,hyderabad,shiva,hills,jubilee,kola,re...
# 13  collection,facebook,bride,heritage,love,india,...
# 14  love,fashion,photography,music,beautiful,video...
# 15  tamil,love,trending,comedy,fun,dance,cute,duet...
# 16  one,wanderlust,time,would,trek,india,day,back,...
# 17  style,collection,fashion,chic,pretty,insta,fas...
# 18  peace,singapore,life,travel,traveler,iceland,b...
#
# [19 rows x 25 columns]

# %%
wrds = ['psychology', 'motivation', 'inspire', 'mind','spiritual']
for i in categories_list[17]:
    print(i,w.similarity(i,'happy'))
# Out:
# psychology 0.017473541
# motivation 0.23326564
# inspiration 0.14630651
# mind 0.198841
# spiritual 0.095140815
