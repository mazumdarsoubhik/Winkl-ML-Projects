# %%
import pandas as pd
import numpy as np
from collections import Counter
import nltk
import psycopg2
from nltk.corpus import stopwords
import re
from itertools import chain 
import math
import time
import logging 
import requests
import json
print("Imported all packages.")
# Out:
# Imported all packages.

# %%
print("Loading GoogleNews...")
from gensim import models
w = models.KeyedVectors.load_word2vec_format(r"F:\Pretrained Models\GoogleNews-vectors-negative300.bin.gz", binary=True, limit=2100000)
print("Loaded GoogleNews!")
# Out:
# Loading GoogleNews...
# Loaded GoogleNews!

# %% [markdown]
# # Changes Fixed
# - hash tag count
# - discarded word substring search
# - Bio based categorization and weighted score
# - Caption size threshold = 3

# %%
def process(array):
    text = re.sub(r'\[[0-9]*\]',' ',str(array))  #Remove Numbers
    text = re.sub("^\d+\s|\s\d+\s|\s\d+$", " ", text) # Remove nums
    text = re.sub(r'\s+',' ',text)  #Remove extra space
    text = re.sub(r"[^a-zA-Z0-9]+",' ',text)  #Remove special characters
    text = text.lower()  #Lower case all
    text = nltk.sent_tokenize(text)  #Tokenize to sentences 
    keywords = [nltk.word_tokenize(sentence) for sentence in text]
    for i in range(len(keywords)):
        keywords[i] = [word for word in keywords[i] if word not in stopwords.words('english')]
    return keywords

def process_with_hash(array):
    hashes = len(re.findall(r'#',str(captions))) #counting hashtags
    text = re.sub(r'\[[0-9]*\]',' ',str(array))  #Remove Numbers
    text = re.sub("^\d+\s|\s\d+\s|\s\d+$", " ", text) # Remove nums
    text = re.sub(r'\s+',' ',text)  #Remove extra space
    text = re.sub(r"[^a-zA-Z0-9]+",' ',text)  #Remove special characters
    text = text.lower()  #Lower case all
    text = nltk.sent_tokenize(text)  #Tokenize to sentences 
    keywords = [nltk.word_tokenize(sentence) for sentence in text]
    raw_cap = len(keywords[0]) # Total number of words in caption
    for i in range(len(keywords)):
        keywords[i] = [word for word in keywords[i] if word not in stopwords.words('english')]
    genuinity_percent = (raw_cap-hashes)*100/raw_cap
    return keywords,genuinity_percent

# %%
conn = psycopg2.connect(host="winkl-production.cpsgstz5cgos.us-west-2.rds.amazonaws.com",port="5432",database="winkl_production", user="winkl", password="Winkl911911")
cur = conn.cursor()
cur.execute('''
SELECT iup.insta_user_id, iu.url, iup.caption 
FROM insta_users as iu,insta_user_posts as iup
WHERE iup.insta_user_id IN (SELECT id FROM insta_users WHERE country='India' LIMIT 100)''')
InstagramAccount = pd.DataFrame(cur.fetchall(),columns=["insta_user_id", "url","caption"])
display(InstagramAccount)

# %% [markdown]
# ### Count hashtags fix
#
# 122727 hindi

# %%
import requests
import json
x = requests.get('http://44.229.68.155/insta_users/get_uncategorized_accounts?limit=10&current_id=122727', headers={'Authorization': 'Token ruor7REQi9KJz6wIQKDXvwtt'})
status = x.status_code
data = x.json()
df = pd.DataFrame(data['users'])
dfnew = pd.DataFrame(columns=['id','handle','name','url','gender','country','captions'], data = df[['id','handle','name','url','gender','country','captions']].values)
dfnew.to_csv(r'E:\Winkl Mains\Task_4_Recategorisation\DATA\test_10_profiles.csv')

# %%
x = 0

display(dfnew.url.iloc[x])
display((dfnew.captions.iloc[x]))
# Out:
# 'https://www.instagram.com/maa_bhukh_lagi_hai/'
# ['भरवा बैंगन\nमसाला भरवा बैंगन और गरमा गरम ghee वाले परांठे खाने का मजा और किसमे है। सही कहा ना।\n.\n.\nRecipe/विधि\nStep 1.बेसन लीजिए उसमे ताजा हरि मिर्च का पेस्ट और लहसुन और लाल मिर्च पाउडर का पेस्ट डाल दीजिए।\n.\nStep 2.अब इसमे हल्दी, धनिया, लाल मिर्च पाउडर साथ मे नमक, साबुत धनिया, जीरा डाल दीजिए, अब थोड़ा तेल डाल कर मिला लीजिए।\n.\nStep 3.हरा धनिया डालिए अब सब को अच्छे से मिला कर मसाला तैयार कर लीजिए।\n.\nStep 4.अब बैंगन मे मसाला भर दीजिए और आलू काट लीजिए।\n.\nStep 5.अब एक kadhai लीजिए उसमें तेल उसमें हरि मिर्च और लहसुन डाल दीजिए अब जीरा थोड़ा फिर आलू और हरि मिर्च का पेस्ट डाल कर पकने दीजिए।\n.\nStep 6.अब बैंगन डाल कर मिला लीजिए और 10 मिनट तक पकने दीजिए।\n10 मिनट मे सब्जी तैयार तो परांठे के साथ खाने का मजा लीजिए।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#indianthali',
#  'मटर-ए-खास पुलाव\nपुलाव पर ghee डाल कर खाने का मजा ही अलग है, और उसमें मटर और गाजर हो तो बात ही क्या। हाँ जल्दी जल्दी मे काजू डालना भूल गया लेकिन आप ना भूलना।\n.\nStep 1.एक pan लीजिए उसमे ghee डालिए फिर लौंग और तेज पत्ता डालिए।\n.\nStep 2.अब इसमें थोड़ी राई दाना और जीरा डालिए फिर उसमें गाजर, प्याज और हरि मिर्च डालिए।\n.\nStep 3.अब इसमें मटर डालिए और मिला लीजिए सब को फिर भिगोया चावल डाल दीजिए और मिला लीजिए।\n.\nStep 4.अब इसमें पानी मिलाए नमक डाले और ढक कर 7-8 मिनट पकने दीजिए।\n.\nStep 5.7-8 मिनट बाद देखिए आप का पुलाव तैयार होगा।\nपानी जितनी आप की ईच्छा हो उससे कम डालना। तो चावल खिले खिले बनेंगे।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#indianfood',
#  'प्याज की कचोरी\nराजस्थान मे आए और प्याज की कचोरी का स्वाद ना लिया ऐसा हो नहीं सकता, दाल-बाटी के साथ साथ इस प्याज कचोरी ने भी राजस्थान के खाने के स्वाद को पूरे भारत मे पहुंचाया है।\n.\nRecipe/विधि\nStep 1.मैदा लीजिए उसमे नमक और अजवाइन डालिए फिर तेल डालिए और पानी डाल कर सौफ्ट आटा तैयार कर लीजिए।\n.\nStep 2.अब मसाला बनाने के लिए kadhai लीजिए उसमें हरि मिर्च, अदरक पेस्ट, सौंफ, साबुत धनिया जीरा दरदरा पीस कर डाल दीजिए अब बारीक कटे प्याज डाल दीजिए।\n.\nStep 3.अब इस पर नमक, लाल मिर्च, धनिया, हल्दी पाउडर डाल दीजिए फिर बेसन और उबला हुआ आलू डाल दीजिए।\n.\nStep 4.अब चाट मसाला और हरा धनिया डाल दीजिए और मसाला ठंडा होने दीजिए।\n.\nStep 5.कचोरी मे मसाला भर कर तल दीजिए मीडियम आँच पर।\nआप की प्याज कचोरी तैयार चाय के साथ मजा लीजिए।तेल की मात्रा उतनी ही डाले जितनी video मे बताए अनुसार आटा मुट्ठी में बंध जाए। \n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#rajasthanifood',
#  'राजस्थानी मशहूर lilva पुलाव (हरे चने का पुलाव)\nसर्दियों के दिनों मे राजस्थान मे हरे चने बहुत होते है इसलिए उससे अलग अलग प्रकार के व्यंजन भी बनाए जाते है जिसमें ये लजीज lilva पुलाव भी है, इसके आगे मटर पुलाव भी फीका है।\n.\nRecipe/विधि\nStep 1.pan लीजिए उसमें तेल/ghee डालिए उसमे लौंग, राई दाना, तेज पत्ता, जीरा डालिए। अब लहसुन, हरि मिर्च, शिमला मिर्च और प्याज डाल दीजिए।\n.\nStep 2.अब आलू डाल दीजिए और कुछ देर बाद हरे चने डाल कर मिला लीजिए अब लाल मिर्च, धनिया और हल्दी पाउडर डाल दीजिए और पकने दीजिए।चाहें तो थोड़ा पानी डाल दीजिए।\n.\nStep 3.अब भीगे हुए चावल डाल दीजिए और मिला लीजिए अब पानी डाल दीजिए और नमक डाल कर 10 मिनट के लिए पकने दीजिए।\n.\nStep 4.10 मिनट बाद देखिए आप का पुलाव तैयार होगा इस पर roasted काजू डालिए और ghee डालिए।\n.\nStep 5.हरा धनिया डाल दीजिए बस तैयार lilva पुलाव मजा लीजिए इसके स्वाद का।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#indianfood',
#  'NAAN (तंदूरी रोटी)\nतंदूरी रोटी का अपना एक अलग मजा है, उसे खा कर एक अलग सी तृप्ति होती है रोज ना सही पर कभी कभी इसे खाने की craving हो जाती है।\n.\nRecipe/विधि\nStep 1.मैदा लीजिए उसमें नमक, थोड़ी sugar अच्छे color के लिए साथ मे बैकिंग powder और तेल थोड़ा फिर सब को मिला लीजिए।\n.\nStep 2.अब दूध के साथ आटा गूँथ लीजिए और 15 मिनट के लिए rest पर रख दीजिए।\n.\nStep 3.अब इस आटे की छोटी छोटी गोलियां बना कर रख दीजिए 10 मिनट के लिए।\n.\nStep 4.अब इसे अपनी ईच्छा के अनुसार बेल लीजिए फिर एक साइड पर butter या Ghee लगाए उस पर थोड़ा धनिया हरा डालिए।\n.\nStep 5.अब दूसरी साइड पर पानी का एक हाथ फेर कर तवे पर डाल के 2 मिनट पका लीजिए फिर तवा उल्टा कर दूसरी साइड को पका लीजिए।\nबस तैयार आप की तंदूरी रोटी।पानी लगी साइड तवे पर डालिएगा। \n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#indianthali',
#  'देसी स्टाइल macaroni Pasta\nगरमा गरम pasta खाने का मजा ही कुछ अलग है और देसी स्टाइल मे बने pasta की बात ही अलग है।\n.\nRecipe/विधि\nStep 1.एक pan लीजिए उसमे तेल डालिए फिर जीरा, प्याज, लहसुन, हरि मिर्च डाल दीजिए उस पर हल्दी, धनिया और लाल मिर्च पाउडर डालिए।\n.\nStep 2.अब इसमे टमाटर और नमक डाल दीजिए फिर टमाटर सॉस डालिए साथ मे तुलसी के पत्ते।\n.\nStep 3.अब गैस बंद कर दीजिए और एक बर्तन मे पानी गर्म कर के पास्ता डाल दीजिए उपर से नमक डाल दीजिए और pasta पकने दीजिए।\n.\nStep 4.pasta पकने के बाद पास्ता को छान लीजिए और जो पानी बचा उसमें से थोड़ा पानी pan मे डाल कर गैस फिर से चालू कर दीजिए।\n.\nStep 5. अब इसमें pasta डाल दीजिए और मिला कर उस पर हरा धनिया डाल दीजिए।\nतैयार आप का देसी स्टाइल pasta, मजा लीजिए।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#rajasthanithali',
#  'राजस्थानी झटपट हरि मिर्च का अचार\nमिर्च का अचार परांठे के साथ खाने मे अलग ही आनंद है।मिर्च का अचार तो सभी को पसन्द आता है।\n.\nRecipe/विधि\nStep 1.राई दाना को दरदरा पीस लीजिए उस पर हल्दी, धनिया पाउडर साथ मे हींग और नमक डाल कर सब को मिला लीजिए।\n.\nStep 2.तैयार मसाले को मिर्च मे भर दीजिए।\n.\nStep 3.अब सरसों का तेल लीजिए उसमें मेथी दाना, राई दाना डाल दीजिए फिर मिर्च डाल कर पकने दीजिए।\n.\nStep 4.5 मिनट पकने के बाद इसमे lemon juice डालिए और 2 मिनट फिर ढक के पकने दीजिए।\n.\nStep 5.अब 2-3 मिनट बिना ढके इसे पकने दीजिए।\nबस तैयार आप का instant अचार/वगारेली मिर्ची\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#rajasthanifood',
#  'प्याज का पराठा पंजाबी स्टाइल\nप्याज का पराठा मुझे आलू पराठा जितना पसन्द तो नहीं लेकिन सुबह सुबह चाय के साथ इसे खाने मे मजा बड़ा आता है।\nआप को पसन्द है? \n.\nRecipe/विधि\nStep 1.बारीक प्याज लीजिए उसमे हरि मिर्च बारीक, हरा धनिया बारीक, जीरा डालिए।\n.\nStep 2.अब लाल मिर्च, धनिया पाउडर और नमक डाल कर मिला लीजिए बस।\n.\nStep 3.अब आलू के परांठे की ही तरह इस मसाले से पराठा तैयार कर लीजिए।\nनमक डालने के बाद इसे ज्यादा देर तक ना रखे परांठे बना ले क्योंकि नमक डालने के बाद पानी छोड़ेगा।\nअब चाय बना लो और मुझे बुला लो प्याज का पराठा खाने के लिए 😂\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#indianfood',
#  'आलू की सब्जी\nपरांठे और आलू की सब्जी सर्दी मे खाने का कुछ खास मजा आता है।इसका कारण है सर्दी मे आलू आते भी अच्छे है।\n.\nRecipe/विधि\nStep 1.आलू उबाल के छोटे छोटे टुकड़ों मे काट लीजिए।\n.\nStep 2.अब pan लीजिए उसमे तेल फिर राई दाना हरि मिर्च और लहसुन और फिर जीरा डालिए अब लहसुन और लाल मिर्च पाउडर का पेस्ट डालिए।\n.\nStep 3.अब आलू डालिए फिर हल्दी पाउडर डालिए मिला लीजिए अब नमक डालिए और हरि मिर्च बड़ी कटी हुई डालिए इससे स्वाद बड़ जाना आलू का अब लाल मिर्च, हल्दी और धनिया पाउडर डालिए।\n.\nStep 4.अब अच्छे से मिला लीजिए।\n.\nStep 5.फिर तिल के दाने डालिए और हरा धनिया बारीक डाल दीजिए।\nतैयार आलू मसाला अब परांठे के साथ मजा लीजिए।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#rajasthanifood',
#  'आज की थाली - Handvo\nढोकला के बाद सबसे ज्यादा पसंद मुझे ये Handvo है बनाने मे आसान और खाने मे तो क्या कहने मतलब बावल चीज़ है।\n.\n.\nआप भी try किजिये...\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#thali #gujratifood #handvo #dhokla #desifood #desikhana #jaipurigers #udaipurphotography #paneerrecipes #alooparatha #paratha #northindianfood #foodholicmumbai #foodphotoaday #buzzfeedfood #foodtalkmumbai #udaipurlove #jaipurblogger #nashta #lunchboxes #f52grams',
#  'बैचलर ब्रेड पकोड़ा\nखाना बनाना आना भी कभी कभी सजा बन जाता है, अब आज ही देख लो सब friends पतंग उड़ा रहे और मुझे पकोड़े बनाने का ऑर्डर दे कर नीचे भेज दिया....\n.\nRecipe/विधि\nStep 1.तो बैचलर पकोड़ा बनाने के लिए बेसन लीजिए उसमें हल्दी, लाल मिर्च, धनिया पाउडर डालिए।\n.\nStep 2.थोड़ा जीरा दाना और थोड़ी अजवाइन भी डालिए। अब थोड़ा नमक, हरि मिर्च और धनिया हरा डाल दीजिए।\n.\nStep 3.अब पानी डाल घोल तैयार कर लीजिए और ब्रेड को 4 टुकड़ों मे काट दीजिए।\n.\nStep 4.अब घोल मे थोड़ा बैकिंग सोडा डाल दीजिए और फिर बस ब्रेड बेसन मे डुबो डुबो कर पकोड़े तल दीजिए।\n.\nStep 5.अब खाना कैसे है, ये भी बताऊ क्या 😂 😂 😂 😂\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#indianfood',
#  'भरवा भिंडी\nभिंडी वो भी भरवा मतलब नाम लेते लेते ही मुहँ मे पानी आजाता है। परांठे के साथ इसको खाने का आनंद शायद ही दुनिया मे किसी और चीज मे होगा।\n.\nRecipe/विधि\nStep 1.लहसुन और लाल मिर्च का पेस्ट लीजिए इसकी जगह सिर्फ लाल मिर्च का पाउडर ले सकते है फिर हरि मिर्च और लहसुन की चटनी लीजिए।\n.\nStep 2.इसमे लाल मिर्च, धनिया, हल्दी पाउडर साथ मे नमक डालिए थोड़ी हींग डालिए बस अब थोड़ा तेल डाल कर मसाला तैयार कर लीजिए।\n.\nStep 3.अब भिंडी मे मसाला भर दीजिए।\n.\nStep 4.kadhai लीजिए उसमे तेल डालिए उसमे लहसुन और हरि मिर्च डालिए फिर अगर मसाला बच जाए तो इसमे डाल दीजिए अब हल्दी डाले फिर भिंडी डाल दीजिए और ढक दीजिए।\n.\nStep 5.8 मिनट बाद देखिए आप की भिंडी पक जाएंगी।\nअब आनंद लीजिए भरवा भिंडी का..\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#rajasthanifood',
#  'हैदराबादी Baghari Sem Phali\nथोड़े ट्विस्ट के साथ हैदराबाद की यह खास Recipe जो हैदराबाद के लगभग हर घर मे खासकर मुस्लिम घरों मे बनाई जाती वहां non-veg चीज़ों के साथ बनाई जाती, लेकिन ये Recipe शाकाहारी है।ट्विस्ट इसमे यह है कि इसमे लोबिया/Chawla dal बड़ी (राजस्थानी) add की गयी है।\n.\nRecipe/विधि\nStep 1.सबसे पहले एक kadhai मे थोड़ा तेल ले कर इसमे Lobia बड़ी को तल दीजिए।\n.\nStep 2.अब एक kadhai मे थोड़ा तेल और ले कर उसमें राई दाना, हरि मिर्च, लहसुन, जीरा डाल दीजिए।\n.\nStep 3.अब लहसुन और हरे धनिया की चटनी डाल दीजिए फिर थोड़ा सा पानी डाल कर भीगी हुई sem phali डाल दीजिए और उस पर नमक और Lobia बड़ी डाल दीजिए।\n.\nStep 4.अब इसे ढक दीजिए 5 मिनट के लिए फिर 5 मिनट बाद हरा धनिया और थोड़ी अजवाइन ताकि खाने के बाद गैस ना हो।\n.\nStep 5.अब इसे आप चावल, मक्की रोटी, परांठे के साथ खाने का आनंद लीजिए।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#rajasthanithali',
#  'Veg पुलाव-\nVeg पुलाव खाने का एक अलग ही मजा है और उसमे मटर और गाजर मिल जाए तो आनंद ही आनंद।\nआप को veg पुलाव मे कौनसी सब्जियां पसन्द है?\n.\nRecipe/विधि\nStep 1.चावल को भिगो लीजिए, अब कुकर मे देसी ghee लीजिए उसमे तेज पत्ता, लौंग, काली मिर्च डालिए फिर हरि मिर्च और लहसुन डालिए।\n.\nStep 2.अब इसमे प्याज, आलू डालिए थोड़ा आलू पकने के बाद इसमे गाजर और जीरा डाल दीजिए।\n.\nStep 3.अब इसमें मटर साथ मे लाल मिर्च पाउडर, हल्दी पाउडर और धनिया पाउडर डाल कर मिला लीजिए।\n.\nStep 4.अब इसमें चावल डालिए और फिर पानी साथ मे नमक डाल दीजिए।\n.\nStep 5.अब इसे ढक कर पकने दीजिए 1-2 सिटी  फिर तैयार आप आपका veg पुलाव।\nमजा लीजिए दही के साथ।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#indianthali',
#  'आलू परांठे का मसाला -\nआलू का पराठा नाम सुन के ही भूख लग जाती है, ऐसा कोई शायद ही होगा जिसे आलू पराठा ना पसन्द हो।\n.\nRecipe/विधि\nStep 1.आलू उबाल दीजिए, फिर एक kadhai लीजिए उसमें तेल फिर ताजातरीन प्याज और हरि मिर्च और हरा धनिया का पेस्ट डालिए।\n.\nStep 2.अब सौंफ,जीरा, साबुत धनिया डालिए फिर इसमें आप हरे धनिया और लहसुन की चटनी डालिए और मिला लीजिए।\n.\nStep 3.अब इसमें आलू का मसाला डाल दीजिए और नमक डाल कर मिला लीजिए।\n.\nStep 4.अब आप इस पर पुदीना डाल दीजिए सूखा हो तो भी चलेगा और फिर हरा धनिया डाल कर मिला लीजिए।\n.\nStep 5.अब इस लजीज मसाले का पराठा बना कर मजे से इसके स्वाद का मजा लीजिए।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#thali',
#  'Methi poori 🌟\nसर्दियों मे गरमा गरम मेथी की पूरी और साथ मे अदरक वाली चाय मिल जाए तो बस और क्या चाहिए, क्यों सही कहा ना।\n.\nStep 1.सबसे पहले मेथी को बारीक काट लीजिए अब गेहूँ का आटा लीजिए उसमे मेथी मिला लीजिए उस पर थोड़ी सूजी डालिए।\n.\nStep 2.अब इसमे नमक, जीरा, हल्दी, धनिया पाउडर और साबुत धनिया थोड़ा सोडा मीठा,अजवाइन डाल दीजिए।\n.\nStep 3.अब ताजा हरि मिर्च और प्याज का पेस्ट डालिए और थोड़ा तेल डाल मिला लीजिए।\n.\nStep 4.जरूरत हो तो पानी डालिए बाकी आटा तैयार हो जाएगा।\n.\nStep 5.अब बस पूरी बना कर तेल मे तल दीजिए।\nतैयार पूरियां मेथी की।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#desikhana',
#  'Instant मिर्ची का अचार-\nपराठा और मिर्च का अचार रोल कर के खाने का जो मजा है वो और किसी चीज मे नही, सही कहा ना।\n.\nRecipe/विधि\nआसानी से और झटपट तैयार होने वाला मिर्ची का अचार\nStep.1 सबसे पहले एक प्लेट में राई दाना लीजिए उसे पीस लीजिए दरदरा अब इसमें हल्दी पाउडर, हींग, धनिया पाउडर और नमक डाल कर मिला लीजिए।\n.\nStep.2 अब मिर्ची में इस तैयार मसाले को भर दीजिए अच्छे से।\n.\nStep.3 अब सरसों का तेल kadhai मे लीजिए उसमें मेथी दाना और राई दाना डालिए फिर मिर्ची डाल दीजिए और ढक दीजिए।\n.\nStep.4 अब 2 मिनट बाद इसमे निम्बु का रस डाल कर फिर 2 मिनट के लिए ढक दीजिए।\n.\nStep.5 अब 2 मिनट बाद ढक्कन हटा कर इसे 2 मिनट और पकने दीजिए बस।\nतैयार आप का instant मिर्ची का अचार।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#rajasthanifood',
#  'रवा इडली/तड़का इडली\nइडली तो हम सभी को पसन्द और जब बात तड़का इडली की हो तो उसका तो जवाब ही नहीं।\n.\nRecipe/विधि\nStep 1.एक कटोरी रवा लीजिए उसमें 3/4 कटोरी दही लीजिए उसमे नमक डाल, मिला लीजिए और 30 मिनट के लिए रेस्ट पर रख दीजिए।\n.\nStep 2.अब तड़का तैयार करने के लिए एक kadhai मे तेल उसमें राई दाना, चना दाल, उड़द दाल, कड़ी पत्ता और काजू डाल दीजिए और दाल का कलर चेंज होने तक पका लीजिए।\n.\nStep 3.30 मिनट बाद सूजी मे थोड़ा पानी डाल घोल को थोड़ा पतला कर दीजिए फिर उसमें ये तैयार तड़का डाल दीजिए फिर हरि मिर्च और बैकिंग सोडा डाल कर घोल को मिला लीजिए।\n.\nStep 4.अब बस इडली कुकर मे इसे रख कर पका लीजिए 10-12 मिनट तक बस फिर चटनी के साथ इसका मजा लीजिए वैसे चटनी की जरूरत नहीं पड़ती।\nतड़का तैयार करते समय ध्यान tadke पर ही देना नहीं तो मेरे जैसे थोड़ा ज्यादा ही पक जाएगा 😂"नजर हटी दुर्घटना घटी" और तड़का थोड़ा ठण्डा होने पर घोल मे डाले। \n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#indianthali',
#  'हरे चने की सब्जी राजस्थानी स्टाइल\nक्या आपने कभी हरे चने की सब्जी खाई है नहीं तो इस सर्दी के मौसम मे के बार जरूर try किजिये अच्छी लगेगी बहुत आसान है।\n.\nRecipe/विधि\nStep 1.एक kadhai लीजिए उसमे तेल डालिए उसमे हरि मिर्च, लहसुन, और जीरा डालिए।\n.\nStep 2.अब इसमे लहसुन और हरे धनिया का पेस्ट डालिए फिर इसमे हल्दी पाउडर और धनिया पाउडर डालिए।\n.\nStep 3.अब पानी डालिए थोड़ा सा ताकि मसाला सही पक जाए और फिर हरे चने डालिए और उस पर नमक डाल दीजिए।\n.\nStep 4.अब इसमे पानी डालिए थोड़ा फिर ढक दीजिए 5-7 मिनट बस।\n.\nStep 5.बस तैयार आप की हरे चने की सब्जी।\nइसे गरमा गरम फूलका रोटी के साथ खाए।\n.\nलाल चटनी - 10-12 लहसुन कलियाँ उसके साथ थोड़ा जीरा और हरा धनिया ज्यादा थोड़ा नमक डाल पेस्ट बना लीजिए फिर उसमे लाल मिर्च का पाउडर मिक्स कर दीजिए।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#rajasthanifood',
#  'आलू की सब्जी और yellow वाले परांठे\nYellow वाले पराठे आलू की सुखी सब्जी के साथ खाने का कुछ अलग ही मजा है अगर ये अनुभव आपने नहीं किया तो भाई सोच लीजिए एक बार कर क्या रहे हो?\n.\n.\nRecipe/विधि - yellow वाले परांठे\n.\nStep 1.गेंहू का आटा लीजिए उसमें नमक साथ मे जीरा, अजवाइन, हल्दी और थोड़ा तेल डाल कर मिला लीजिए।\n.\nStep 2.अब पानी डाल आटा तैयार कर लीजिए soft. \n.\nStep 3.अब आटे को थोड़ा rest दीजिए 30 मिनट।\n.\nStep 4.अब 30 मिनट बाद वीडियो मे बताए अनुसार पराठा बना कर ghee मे सेक लीजिए।\nबस फिर आलू की सब्जी के साथ मजे से इसका मजा लीजिए।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#indianthali',
#  'आज की थाली - मसाला अरबी की सब्जी और पकोड़ा कढ़ी और फूलका रोटी..\n.\nतो आप को मसाला अरबी पसन्द है या नहीं?\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#paratha #alooparatha #desikhana #udaipurwale #udaipurfood #jaipurigers #thaali #desifood #rajasthani #roti #kadhichawal #northindianfood #foodtalkmumbai #lunchspecial #gharkakhana #daal #paneerrecipes #foodphotoaday #udaipurphotography #aloo #biryanilovers',
#  'Green tea🌟\n.\n.\nThank u @khadikangravalley प्रोडक्ट भेजने के लिए।\n@khadikangravalley health care products बनाते है, खासकर ग्रीन टी, ग्रीन कॉफी और भी बहुत से products है एक बार जरूर देखे ।\n.\nरही बात ग्रीन टी तो बाकी ग्रीन टी के मुकाबले बहुत ही फ्रेश और अच्छी है अब दूध वाली चाय से मुकाबला तो होना नहीं।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#instagramreels',
#  'Quick साबूदाना खिचड़ी recipe\nशायद ही कोई ऐसा हो जिसे साबूदाना खिचड़ी ना पसन्द हो सही कहाँ ना।\n.\nRecipe quick\n.\nविधि -\nStep 1. सर्वप्रथम साबूदाना लीजिए उसे अच्छे से धोने के बाद, जो extra पानी है वो निकाल कर 3-4 घंटे के लिए भिगो कर रख दीजिए।\n. \nStep 2. अब 3-4 घंटे के बाद साबूदाना मे हल्दी, लाल मिर्च पाउडर और नमक साथ मे धनिया पाउडर मिला कर रख दीजिए साइड मे।\n. \nStep 3. अब एक pan लीजिए उसमे कुछ मूँगफली डाल कर roast कर साइड मे रख दीजिए।\n.\nStep 4. अब pan मे जीरा फिर आलू डाल कर आलू को पकने दीजिए फिर हरि मिर्च डालिए फिर कढ़ी पत्ता डालिए। \n.\nStep 5. अब साबूदाना डाल कर कुछ देर 2-3 मिनट पकने दीजिए।अब मूँगफली डाल दीजिए।अब थोड़ा हरा धनिया और बस तैयार खिचड़ी।दही के साथ मजे से लुफ्त लीजिए खिचड़ी का साथ मे share किजिये ये आसान recipe अपने मित्रों के साथ। \n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#rajasthanithali',
#  'Sweet potato snack 🌟🌟\n.\nSweet potato को aap एक बार इस तरह से बना कर खाइए मजा आएगा।\n.\nबहुत ही आसान...\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#instareel',
#  'मटर पत्ता गोभी ढाबा स्टाइल\nपत्ता गोभी मटर के साथ सर्दियों मे गरमा गरम परांठे खाने का मजा कुछ अलग ही होता है। सही कहा ना!\n.\nRecipe/विधि\n.\nStep 1.एक kadai लीजिए उसमें राई दाना फिर हरि मिर्च और लहसुन डालिए।\n.\nStep 2.अब इसमे आलू डालिए उसे पकने दीजिए अब थोड़ा जीरा और फिर लहसुन और लाल मिर्च की चटनी साथ मे हल्दी और धनिया पाउडर डालिए।\n.\nStep 3.अब टमाटर डालिए अब थोड़ा पानी फिर नमक डालिए अच्छे से मिला लीजिए।\n.\nStep 4.अब इसमे पत्ता गोभी डालिए और मिला कर ढक दीजिए 10 मिनट के लिए।\n.\nStep 5.बस 10 बाद देखिए तैयार हो जाएगी सब्जी और अगर नहीं पकी तो और थोड़ी देर पकने दीजिए।\n.\nअब परांठे बना कर खा लीजिए।\n.\n.\n@maa_bhukh_lagi_hai\n.\n#rajasthanifood',
#  'आज की थाली - बेसन गट्टा सब्जी और ghee वाले परांठे...\n.\nकभी सोचता हूं अगर ये बेसन गट्टा सब्जी हम राजस्थानियों की जिंदगी मे ना होती तो हम राजस्थानियों का क्या होता 😂\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#besangatte #besangatta #thali #udaipurwale #jaipurigers #desikhana #paratha #alooparatha #udaipurfood #rajasthan #dalbati #northindianfood #lunchtime #foodholicmumbai #foodbossindia #paneer #paneerrecipes #sabzi #jaipurbloggers #jainfood #grubzone',
#  'लौकी की मसालेदार सब्जी -recipe \nलौकी की सब्जी बहुत से लोगों को नहीं पसन्द लेकिन एक बार इस तरह बना कर देखिये आप, कसम से मजा आजाये गा।\n.\nRecipe\n.\nविधि - step 1. एक kadai लीजिए उसमें राई, मेथी दाना और हरि मिर्च और लहसुन डालिए साथ में जीरा डालिए।\n.\nStep 2. अब इसमें हरि मिर्च का पेस्ट डालिए साथ मे लहसुन और धनिया की चटनी डालिए और मसाला पकने दीजिए।\n.\nStep 3. अब इसमें टमाटर फिर हल्दी पाउडर और धनिया पाउडर अब थोड़ा पानी डालिए।\n.\nStep 4. अब नमक और हींग डालिए और साथ मे कटी हुई लौकी डालिए और ढक दीजिए 10 मिनट के लिए।\n.\nStep 5. 10 मिनट बाद देखिए लौकी पक गयी होगी तो अब इसमें 2 चम्मच दही डालिए और मिला लीजिए और 2 मिनट पकने दीजिए, बस तैयार लौकी की सब्जी मसालेदार।\n.\n.\n@maa_bhukh_lagi_hai\n.\n#indianfood',
#  'बैचलर पुलाव-\nपुलाव ऐसा जो हर कोई बना ले, और बैचलर नाम की जो एक जात है उसके लिए तो ये किसी वरदान से कम नहीं झटपट और स्वादिष्ट पुलाव जो कुछ मिनटों मे तैयार हो जाए।hostel मे बनाने का बड़ा ही मजा आता था इसे। \n.\nRecipe\n.\nविधि - step 1. कुकर लीजिए उसमें ghee लीजिए उसमें राई दाना, हरि मिर्च और लहसुन बारीक कटे हुए डाल दीजिए।\n.\nStep 2. अब प्याज डालिए फिर तेज पत्ता और लौंग डालिए फिर पकने दीजिए अब मूँगफली डालिए अब एक कटोरी लीजिए उसमें लाल मिर्च पाउडर, हल्दी और नमक और पानी डाल कर अच्छे से मिला कर कुकर मे डाल दीजिए।\n.\nStep 3. अब मसाला पक जाए तो मटर डालिए और फिर थोड़ा पानी डालिए और उसपर थोड़ा नमक डालिए।\n.\nStep 4. अब पानी डालिए जितना चावल उससे डेड गुना। फिर उसमे चावल डाल दीजिए जो आपने धो के रखे है।\n.\nStep 5. अब हरा धनिया और सब मिला लीजिए और कुकर बंद कर के पकने दीजिए 2 सिटी लीजिए।\n.\nStep 6. तैयार है बैचलर पुलाव दही, पापड़, ghee, अचार के साथ मजे से खाइए।\n.\n. \n@maa_bhukh_lagi_hai\n.\n#rajasthanifood',
#  'Masala Lobia/chawli Sabji (Rajasthani style)\nक्या आपने कभी लोबिया की ऐसी स्वादिष्ट सब्जी खाई है, नहीं तो एक बार जरूर try किजिये इस Recipe को।\n.\nRecipe\n.\nविधि -\nStep 1. एक kadai लीजिए उसमें राई, मेथी दाना लहसुन और हरि मिर्च डालिए।\n.\nStep 2. अब बारीक प्याज साथ मे कढ़ी पत्ता डालिए और पकने दीजिए।\n.\nStep 3. अब लहसुन और धनिया की चटनी साथ मे हल्दी, लाल मिर्च और धनिया पाउडर डालिए।\n.\nStep 4. अब cooker में पके हुए Lobia kadai मे डाल दीजिए और उस पर नमक डाल दीजिए बस।\n.\nStep 5. थोड़ा हरा धनिया और बस तैयार मसालेदार Lobia की सब्जी।\n.\n.\n@maa_bhukh_lagi_hai\n.\n#rajasthanithali',
#  'पाव भाजी फ्राइड इडली\n.\nफ्राइड इडली थोड़ा पाव भाजी ट्विस्ट के साथ, कुछ अलग स्वाद, कुछ अलग इश्क हो जाना इस फ्राइड इडली के साथ आपको। \n.\n.\nRecipe/विधि\n.\nStep 1. Kadai मे तेल लीजिए उसमें राई दाना, फिर हरि मिर्च फिर प्याज साथ मे थोड़ा जीरा डालिए।\n.\nStep 2. अब कढ़ी पत्ता फिर शिमला मिर्च डालिए फिर टमाटर साथ मे सुखी लाल मिर्च की चटनी फिर लाल मिर्च पाउडर, धनिया पाउडर, हल्दी पाउडर डालिए और मिला लीजिए।\n.\nStep 3. अब थोड़ा नमक और फिर मिला लीजिए अब कटी हुई इडली डाल दीजिए और मिला लीजिए।\n.\nStep 4. अब पावभाजी मसाला डालिए जितनी आप की श्रद्धा बस फिर मिला लीजिए।\n.\nStep 5. अब हरा धनिया ईच्छा हो तो निम्बु का रस भी मिला सकते है।\nबस तैयार फ्राइड इडली पाव भाजी के ट्विस्ट के साथ, लुत्फ लीजिए चाय के साथ ।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#indianfood',
#  'Tava Dhokla⭐🌟 -\nRecipe - एक कप rava लीजिए उसमे आधा कप दही मिलाए। अब इसमें थोड़ा पानी डाल कर अच्छे से सब कुछ मिला दीजिए।\n. \nअब इसमें मटर, हरि मिर्च और नमक डाल कर अच्छे से मिलाए अब ऑइल डाले एक चम्मच फिर मिला लीजिए।अब इसमे baking सोडा मिलाए आधा चम्मच। \n. \nअब एक Tava या pan लीजिए उसके center मे cookie cutter रखिए फिर oil डालिए उसमे राई फिर हरि मिर्च चाहें तो कढ़ी पत्ता फिर तैयार घोल को डाल दीजिए उस पर लाल मिर्च पाउडर डाल कर ढक दीजिए। \n. \nबीच बीच मे देखते रहे कहीं जले नहीं और पकने के बाद निकाल लीजिए चाहें तो तड़का डालिए बाकी ऐसे भी मस्त लगता।\n.\n@maa_bhukh_lagi_hai\n.\n.\n#instareel',
#  'Veg Sandwich (Rajasthani touch)🌟⭐-\nRecipe - सबसे पहले बारीक कटे हुए प्याज लीजिए फिर टमाटर साथ मे शिमला मिर्च बारीक।\n. \nअब इसमें बारीक हरि मिर्च कटी हुई साथ मे Red chilli flakes डालिए साथ मे नमक डालिए। \n.\nRajasthani Touch के लिए इसमे Rajasthani Dry Red chilli chutney डालिए साथ मे टमाटर साॅस डालिए।\n.\nअब सभी चीज़ों को एक साथ मिला लीजिए। अब एक ब्रेड लीजिए उसकी एक साइड पर हरि मिर्च की चटनी लगाए। \n.\nअब तैयार Mixture को दूसरी ब्रेड की एक साइड पर रख कर ब्रेड को चटनी लगी ब्रेड से कवर कर लीजिए अब ब्रेड को दो टुकड़ों मे काट दीजिए।\n.\nअब उस पर नमकीन डाल दीजिए फिर थोड़ा धनिया और बस मजा ले कर खाइए।\n.\n@maa_bhukh_lagi_hai\n.\n#reelsvideos',
#  'मसाला अरबी की सब्जी\nक्या आप को अरबी की सब्जी पसन्द है? पसन्द तो होगी है स्वादिष्ट जो लगती है। इसके साथ परांठे हो गरमा गरम तो बात ही अलग होती है।\n.\nविधि -\nStep 1.अरबी को कुकर मे पका लीजिए और फिर छिलके उतार कर छोटे छोटे टुकड़े मे काट दीजिए।\n.\nStep 2.अब एक kadai लीजिए उसमे थोड़ी राई दाना, फिर बारीक लहसुन और हरि मिर्च डालिए।\n.\nStep 3.अब लहसुन की चटनी अगर है तो बाकी चलेगा, फिर हल्दी थोड़ी और लाल मिर्च पाउडर।\n.\nStep 4.अब अरबी डाल दीजिए और मिला दीजिए अब इस पर लाल मिर्च पाउडर, हल्दी पाउडर, धनिया पाउडर डाल दीजिए और साथ मे नमक भी।\n.\nStep 5.अब बस सब को अच्छे से मिला दीजिए फिर धनिया हरा और बस थोड़ा क्रिस्पी हो जाए अरबी तो बंद कर दीजिए गैस बस। खेल खल्लास...\n.\n.\n@maa_bhukh_lagi_hai\n.\n#rajasthanifood',
#  'हांडी वाले आलू मटर\nआलू मटर की सब्जी किसे नहीं पसन्द, सभी को पसन्द है। बहुत ही आसान recipe ले कर आया हूँ आलू मटर की और लाल चटनी की भी recipe लिख रहा हूँ।\n.\nRecipe आलू मटर in Handi -\n. \n- एक हांडी लीजिए उसमे तेल डालिए फिर राई दाना उसके बाद हरि मिर्च और लहसुन फिर आलू और थोड़ा जीरा और पकने दीजिए अब लाल चटनी डालिए साथ मे हल्दी और धनिया पाउडर अब थोड़ा पानी डालिए मसाला पकने दीजिए।\n.\nअब मटर डालिए साथ मे नमक और ढक दीजिए 2 मिनट के लिए फिर 2 मिनट बाद थोड़ा पानी और डालिए फिर ढक दीजिए अब 5 मिनट बाद देखिए सब्जी तैयार हो गई अब हरा धनिया और बस तैयार सब्जी।\n.\nलाल चटनी recipe - 10-12 लहसुन की कलियाँ लीजिए अब थोड़ा जीरा फिर बहुत सारा हरा धनिया और फिर थोड़ा नमक और 2 चम्मच पानी फिर बना दीजिए पेस्ट और फिर इस पेस्ट मे मिला दीजिए लाल मिर्च का पाउडर अपने हिसाब से जीता तीखा आप को पसन्द बस तैयार चटनी।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#rajasthanithali',
#  'राजस्थान की शान The दाल-बाटी\nअब इसकी क्या तारीफ करू इस दाल-बाटी के स्वाद के आगे तो मेरे शब्द फीके पड़ जाते है।\n.\nRecipe/विधि - दाल-बाटी\nStep 1. गेहूँ का आटा लीजिए उसमे मक्की का आटा और बेसन डालिए।\n.\nStep 2. अब इसमें नमक, जीरा, अजवाइन, साबुत धनिया और सौंफ डालिए।\n.\nStep 3. अब इसमें papad khar चुटकी भर या बैंकिंग सोडा मिला लीजिए साथ मे तेल डालिए।\n.\nStep 4. अब मिलाने के बाद पानी डाल कर अच्छे से आटा तैयार कर लीजिए अब 30 min. का rest दीजिए।\n.\nStep 5. अब इस तैयार आटे से बाटी बना कर इसे बाटी के कुकर मे पकने के लिए रख दीजिए।\n.\nStep 6. जब बाटी पूरी तरह पक जाए तो इन्हें ghee मे थोड़ी देर डुबो दीजिए फिर बस दाल के साथ इस लजीज बाटी का मजा लीजिए।\nदिल से बनाना इस बाटी को बिना दिल के बाटी ना बनेगी, खाने से मोहब्बत ऐसे नहीं होती दिल लगाना पड़ता है।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#rajasthanifood',
#  'मसाला मेथी पराठा/पूडी-\nसर्दी का मौसम और गरमा गरम मेथी की पुडी साथ मे मिर्ची का अचार, ये लिखते लिखते खाने का मन कर गया 😂..\n.\nRecipe\n.\nविधि - step 1. पेस्ट तैयार करने के लिए लहसुन, कुछ हरि मिर्च थोड़ा अदरक साथ मे प्याज डाल कर एक पेस्ट बना लीजिए ज्यादा बारीक ना करना।\n.\nStep 2. बारीक मेथी काट लीजिए उस पर गेहूं का आटा साथ मे मक्की का आटा और बेसन डाल दीजिए।\n.\nStep 3. अब इस पर तैयार पेस्ट डालिए साथ मे बैकिंग सोडा उस पर हल्दी पाउडर, लाल मिर्च पाउडर और धनिया पाउडर डालिए।\n.\nStep 4. थोड़ी अजवाइन थोड़ा जीरा फिर थोड़ी हींग डालिए अब तेल डाल कर मिला लीजिए।\n.\nStep 5. पानी थोड़ा सा डालिए और आटा तैयार कर के पराठा बना कर तवे पर सेक लीजिए।\n.\nअब दही के साथ अचार के साथ इसका मजा लीजिए और मुझे याद कर के बोलिए अच्छा बच्चा है। 😂\n.\n.\n@maa_bhukh_lagi_hai\n.\n#northindianfood',
#  'आज की थाली - गुजराती स्पेशल- आलू की सब्जी, रोटी और khatti mitthi tuvar की दाल...\n.\n.\nक्या आपने कभी गुजराती tuvar दाल खाई है?\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#alooparatha #paneerparatha #aloomatar #thali #udaipurblogger #jaipurbloggers #rajasthani #desifood #roti #gharkakhana #bhindi #dalbati #daltadka #lunchspecials #rajasthanifood #foodtalkmumbai #foodpicsofinstagram #northindianthali #udaipurphotography #paneer #parathe',
#  'आज की थाली - भरवा मिर्ची, भरवा भिंडी और ghee वाले परांठे....\n.\nऔर क्या बोलू इस थाली के बारे में.... शब्द नहीं है बस स्वाद ही स्वाद है....\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#parantha #lacchaparatha #bhindimasala #indianthali #udaipurwale #jaipurigers #rajasthanifood #rajasthan #bainganbharta #desikhana #masalabhindi #khana #jainfood #sabzi #bharelamarcha #lunchtime #foodholicmumbai #foodphotoaday #northindianfood #udaipurblog #bharwabaingan',
#  'आज की थाली - राजस्थानी बेसन गट्टा सब्जी मसालेदार और ghee वाले परांठे...\n.\n.\nआजाओ थाली तैयार है,....\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#parathas #alooparatha #besangatte #besangatta #udaipurite #jaipur_diaries #thali #rajasthanithali #rajasthani #dalbati #gujratifood #gharkakhana #rajasthaniculture #achar #khichdi #lunchspecial #foodtalkmumbai #foodpicsofinstagram #udaipurdairies #rajma #desifood',
#  'आज की थाली - फाफड़ा के साथ मीठी कढ़ी और मिर्ची.....\n.\n.\nशाम की चाय के साथ फाफड़ा मिल जाए तो बस और क्या चाहिए..... मजा नि life...\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#paratha #lacchaparatha #fafda #thaali #rajasthanifood #rajasthan #desifood #udaipurwale #jaipurbloggers #gujjufood #rajkachori #jainfood #gujju_amdavadi #nashta #foodartblog #f52gram #northindianfood #udaipurphotography #paneerrecipes #fafdajalebi #dhokla',
#  'हिंदू व्रतों में केवल शीतला सप्तमी का व्रत ही ऐसा है जिसमें बासी भोजन किया जाता है। इस दिन घर में ताजा भोजन नहीं बनाया जाता। एक दिन पहले ही भोजन बनाकर रख देते हैं। फिर दूसरे दिन प्रात:काल महिलाओं द्वारा शीतला माता का पूजन करने के बाद घर के सब व्यक्ति बासी भोजन को खाते हैं।\nशीतला माता का मंदिर वटवृक्ष के समीप ही होता है। शीतला माता के पूजन के बाद वट का पूजन भी किया जाता है।मां शीतला का पर्व किसी न किसी रूप में देश के हर कोने में मनाया जाता है। विशेष कर चैत्र माह के कृष्ण पक्ष की अष्टमी को शीतला सप्तमी-अष्टमी का पर्व मनाया जाता है। इस पर्व को बसोरा (बसौड़ा) भी कहते हैं। बसोरा का अर्थ है बासी भोजन। शीतला माता हर तरह के तापों का नाश करती हैं और अपने भक्तों के तन-मन को शीतल करती हैं।\n.\nआज की थाली - पूरी, पकोड़े, भरवा मिर्ची, काकोडे की सब्जी, मसाला दही और बर्फी/बेसन चक्की\n.\nआप को और आपके परिवार को शीतला सप्तमी की हार्दिक शुभकामनाएं\n.\n.\n#parathas #paneerparatha #alooparatha #indianthali #udaipurblogger #jaipurbloggers #rajasthanithali #poori #masalabhindi #pakoda #desikhana #gujratifood #bhindi #bharelamarcha #mithaibox #lunchtime #foodholicmumbai #foodphotoaday #udaipur #milkcake #matarpaneer',
#  'शाम की छोटी-छोटी भूख के लिए चाय के साथ rava handvo आप सब के लिए तैयार है....\n.\n.\nले सको तो लेलों 😂😂😂😂\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#handvo #handva #khandvi #udaipur_diaries #jaipurfoodblogger #thali #rajasthan #khaman #desifood #gujratithali #sevtamatar #khana #jainfood #udaipurvlogz #biryanilover #lunchspecial #foodtalkmumbai #foodpicsofinstagram #northindianfood #foodiliciousmumbai #paneer',
#  'Prashad (प्रसाद) - सूजी/Rava हलवा.\n"Happy Krishna Janmashtami"\n.\nKrishna janam -\nIn the bhagwat purana, there is a story in which Bhudevi, the earth goddess, appears before Vishnu in the for of cow, and describe the corruption and selfishness that has taken root among human beings. Vishnu promise her that he will come to earth as a cowherd (Krishna) to protect her. The other belief is that every time Visnhu takes an avatar,Devi too is born. The relationship between the Shiva and Shakti traditions is always one of husband and wife, but the one between Shakti and Vaishnava is variable. Devi can be wife, firend, sister. So, Vishnu comes in the form that Devi requires.\n.\n"jai jai shree Radhe"\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#sujihalwa #halwa #halwapuri #thaali #sweetudaipur #jaipurigers #rajasthanifood #rajasthani #desikhana #indiansweet #mithai #dalbati #gajarhalwa #badammilk #krishnajayanthi #sabudanakhichdi #foodphotoshoot #f52gramsfoodpic #northindianthali #udaipurdiaries #alooparatha',
#  'सूजी का हलवा... झटपट और लजीज\n.\n.\n.\nक्या आप को पसंद है सूजी का हलवा?\n.\n.\n.\n#purihalwa #shreekhand #aamras #aamraspuri #mitha #gajarkahalwa #delhifoodlover #rasgullas #desighee #kajubarfi #ricekheer',
#  'आज की थाली - राजस्थानी ढोकला और खड़ी उड़द दाल, तिल का तेल और पापड़\n.\nराजस्थानी ढोकला - मक्की के आटे मे मसाले डाल कर उसे स्टीम कर के बनाए जाने वाला ये ढोकला राजस्थान मे बडा ही प्रसिद्घ है, वैसे तो ये सर्दियों मे ज्यादा खाया जाता है लेकिन बारिश मे भी इसे खाने का मजा कुछ अलग ही है।\n. \nखड़ी उड़द दाल - खड़ी शब्द से मतलब है कि इस दाल को बिना तड़के से तैयार किया जाता है, हरि मिर्च के ताजे पिसे हुए मसाले के साथ।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#paratha #paneerparatha #jainfood #indianthali #udaipurite #jaipurfashionblogger #marwadi #rajasthanidhokla #desifood #dalbatichurma #daal #indorifood #indorizayka #platinggoals #lunchtime #foodholicmumbai #foodartblog #northindianfood #udaipurblog #papad #shahipaneer',
#  'राजस्थानी मक्की ढोकला की एक झलक जिसे देख कर मुहँ मे पानी आजाए...\n.\n.\n#dalbatilovers #littichokha #gharkithali #traditionalfoods #rajasthanclicks #jaipurfoodbloggers #citypalaceudaipur #curlytales #northindianfoods #daltadka🍲 #upma',
#  'राजस्थानी बेसन गट्टा सब्जी की एक झलक...\n..\n.\n.\nमसालेदार बेसन गट्टा\n.\n.\n#besangattekisabji #rajmachawal #kadhichawal #biryani #gulabjamuncake #thalifood #poorimasala #cholechawal #raita #rajkachori #dalchawal #chapati',
#  'आज की थाली - सूखे बेसन गट्टे की सब्जी, घी वाले परांठे और पापड़.\n.\nये गट्टा सब्जी अलग है राजस्थान मे बनने वाली सब्जी से इसमे प्याज और टमाटर का पेस्ट नहीं डाला गया है, यह आलू की सुखी सब्जी की तरह बनाई गयी है। इसे आप रोटी के साथ भी खा सकते है और चाय के साथ स्नैक्स के रूप में भी।\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#parantha #lacchaparatha #besangatte #ub #pinkcityjaipur #rajasthanithali #desikhana #rajasthan #thali #achar #khana #besangatta #bhindi #jainfood #aloo #lunchboxes #foodtalkmumbai #foodphotoaday #northindianthali #udaipurtourism #matarpaneer',
#  'आज की थाली - अचारी लौकी की जायकेदार सब्जी, मीठा दही, Amit ji wali Bikaji और ghee वाले परांठे\n.\nजिसको नहीं पसन्द लौकी उसे tag करो और दिखाओ और परेशान करो....\n.\n.\n#paratha #paneerparatha #lauki #thaali #udaipurwale #jaipur_diaries #rajasthani #dalbati #marwadi #desifood #aamraspuri #bhindi #jainfood #sabzi #lunchspecial #foodphotoaday #foodartblog #northindianfood #udaipurphotography #matarpaneer #bhujiya',
#  'आज की थाली - कुछ बोलने की जरूरत तो है नहीं, है क्या जरूरत..\n.\nक्या आप जानते है कि छोले की सब्जी के कितने types है इंडिया मे?\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#cholepuri #cholechawal #chole #thali #udaipurblogger #jaipurfood #rajasthan #rajasthanifood #gharkakhana #desikhana #cholebhature #punjabifood #bhindimasala #achar #lunchboxes #foodtalkmumbai #foodpicsofinstagram #northindianthali #udaipurphotography #paneer #poori',
#  'आज की थाली - भरवा मिर्ची, ghee वाले परांठे और स्वाद गोली.....\n.\nअगर ये थाली देखने के बाद भी आप Caption पढ़ने की ईच्छा रखते है तो भाई आप खाने के सच्चे आशिक नहीं हो 😂..\n.\n.\n#paratha #lacchaparatha #bharelamarcha #indianthali #udaipurite #jaipuri #rajasthanithali #rajasthani #marathifood #kandapoha #trell #viralvideos #jainfoodie #bharwabaingan #paneerrecipes #lunchtime #f52gram #foodholicmumbai #northindianfood #udaipur #curlytales',
#  'आज की थाली - आलू मटर, ghee वाले परांठे और मूँगदाल कचोरी....\n.\nKachori - school मे मेरी friend थी Payal Pachori और dinner table पर मेरी best friend है ये मूँगदाल कचोरी...\n.\nकचोरी कौनसी पसन्द है प्याज या मूँगदाल...? \n.\n.\n#parantha #alooparatha #aloo #matarpaneer #ub #jaipurtourism #thaali #kachori #rajkachori #rajasthanifood #desikhana #sabzi #instaudaipur #jainfood #lunchspecials #foodartblog #foodphotoaday #lackcity #udaipurtourism #pinkcityjaipur #rajasthantourism',
#  'आज की थाली - शाही राजस्थानी Churma ladoo.\nChurma ladoo राजस्थान की ही तरह गुजरात मे और मध्यप्रदेश में भी बनाए जाते जहां राजस्थान और मध्यप्रदेश मे इसे दाल बाटी के साथ बनाए जाते है तो वही गुजरात मे इसे पूरी, vaal nu shaak के साथ परोसा जाता है।..\n.\nआज अमावस्या है, इस अमावस्या को हरियाली अमावस्या भी कहा जाता है राजस्थान मे।श्रावण मास भी है इस दिन शिव भगवान को Churma ladoo का भोग लगाया जाता है।\n.\n.\n@maa_bhukh_lagi_hai\n.\nRepost करने से पहले पूछ ले...\n.\n.\n#ladoo #churmaladoo #dalbatichurma #udaipurblog #jaipurjewellery #desifood #rajasthanithali #thali #dalbati #gulabjamun #mithaibox #churma #indorifood #jaipurphotography #mithai #foodtalkmumbai #foodpicsofinstagram #rajasthanistyle #fatehsagarlake #udaipurdairies #rajasthan_diaries',
#  'आज की थाली - शाही राजस्थानी Churma ladoo.\nChurma ladoo राजस्थान की ही तरह गुजरात मे और मध्यप्रदेश में भी बनाए जाते जहां राजस्थान और मध्यप्रदेश मे इसे दाल बाटी के साथ बनाए जाते है तो वही गुजरात मे इसे पूरी, vaal nu shaak के साथ परोसा जाता है।..\n.\nआज अमावस्या है, इस अमावस्या को हरियाली अमावस्या भी कहा जाता है राजस्थान मे।श्रावण मास भी है इस दिन शिव भगवान को Churma ladoo का भोग लगाया जाता है।\n.\n.\n@maa_bhukh_lagi_hai\n.\nRepost करने से पहले पूछ ले...\n.\n.\n#ladoo #churmaladoo #dalbatichurma #udaipurblog #jaipurjewellery #desifood #rajasthanithali #thali #dalbati #gulabjamun #mithaibox #churma #indorifood #jaipurphotography #mithai #foodtalkmumbai #foodpicsofinstagram #rajasthanistyle #fatehsagarlake #udaipurdairies #rajasthan_diaries',
#  'सूजी /Rava Dhokla...\nमुझे ये खम्मण से भी अच्छा लगता है, बस साथ मे हरि मिर्च की चटनी हो तो जन्नत \n.\n.\nआप को क्या पसन्द ढोकला या खम्मण?\n.\n.\n#dhokla #gujratifood #vadodarafoodies #ub #khaman #khamandhokla #instaudaipur #ahemdabadfoodie #gujrati #chutney #upma #jaipurtourism #lackcity #khana #rajasthantourism #gujjus #mumbaistreetfood #delhifoodie #milkcake #udaipurtourism #pinkcityjaipur',
#  'सूजी /Rava Dhokla...\nमुझे ये खम्मण से भी अच्छा लगता है, बस साथ मे हरि मिर्च की चटनी हो तो जन्नत \n.\n.\nआप को क्या पसन्द ढोकला या खम्मण?\n.\n.\n#dhokla #gujratifood #vadodarafoodies #ub #khaman #khamandhokla #instaudaipur #ahemdabadfoodie #gujrati #chutney #upma #jaipurtourism #lackcity #khana #rajasthantourism #gujjus #mumbaistreetfood #delhifoodie #milkcake #udaipurtourism #pinkcityjaipur',
#  'जिन्दगी मैं अभी तक जितनी मिठाइयां मैंने Taste की है उनमें से "gulabjamun", मेरी favorite Dessert की list मैं Top पर आता है। gulabjamun is not just food for me, it\'s love and festival.\n.\nजब आप उस चासनी के प्यार मैं डूबे हुए गुलाब जामुन की first bite लेते हैं तो आप अपनी सारी परेशानियां भूल जाते है। उसकी softness और उसका स्वाद आप उसकी हर bite मे अनुभव करते हैं और उसके इस लजीज स्वाद की वजह से आप के मुँह से "mmm yum yumm" जैसी आवाजें आने लगती। आप की eyes close हो जाती है और आप इस gulabjamun के स्वाद में खो जाते हैं।\n.\ngulabjamun एकमात्र traditional मिठाई है जिसने Food के साथ experiment करने वालों को निराश ना किया उन्होने इसे जब vanilla Ice cream के साथ खाया तो gulabjamun ने अपना और इस Ice cream का स्वाद और बढ़ा दिया। मैं अगर इसे "Dessert of God" कहूँ तो भी गलत नहीं मुझे लगता है lord Krishna भी इस gulabjamun को चांदी के चम्मच के साथ खाते होंगे।\n.\n.\n#gulabjamun #rasgulla #udaipurdairies #udaipur #rajasthanifood #desikhana #indianthali #rajasthani #butterchicken #buzzfeedfood #bangloreblogger #halwa #jainfood #jaipurbloggers #jaipurphotography #vforveggie #northindianfood #lunchspecial #foodartblog #foodphotoaday #paneer',
#  'जिन्दगी मैं अभी तक जितनी मिठाइयां मैंने Taste की है उनमें से "gulabjamun", मेरी favorite Dessert की list मैं Top पर आता है। gulabjamun is not just food for me, it\'s love and festival.\n.\nजब आप उस चासनी के प्यार मैं डूबे हुए गुलाब जामुन की first bite लेते हैं तो आप अपनी सारी परेशानियां भूल जाते है। उसकी softness और उसका स्वाद आप उसकी हर bite मे अनुभव करते हैं और उसके इस लजीज स्वाद की वजह से आप के मुँह से "mmm yum yumm" जैसी आवाजें आने लगती। आप की eyes close हो जाती है और आप इस gulabjamun के स्वाद में खो जाते हैं।\n.\ngulabjamun एकमात्र traditional मिठाई है जिसने Food के साथ experiment करने वालों को निराश ना किया उन्होने इसे जब vanilla Ice cream के साथ खाया तो gulabjamun ने अपना और इस Ice cream का स्वाद और बढ़ा दिया। मैं अगर इसे "Dessert of God" कहूँ तो भी गलत नहीं मुझे लगता है lord Krishna भी इस gulabjamun को चांदी के चम्मच के साथ खाते होंगे।\n.\n.\n#gulabjamun #rasgulla #udaipurdairies #udaipur #rajasthanifood #desikhana #indianthali #rajasthani #butterchicken #buzzfeedfood #bangloreblogger #halwa #jainfood #jaipurbloggers #jaipurphotography #vforveggie #northindianfood #lunchspecial #foodartblog #foodphotoaday #paneer',
#  'आज की थाली - Ghee वाले परांठे साथ है मसाला भिंडी और हरि मिर्ची के papad....\n.\n.\nभिंडी की सब्जी देख पहला ख्याल क्या आया आप के दिल मे..? \n.\n.\n#bhindi #bhindimasala #masalabhindi #paratha #alooparatha #udaipurwale #rajasthanithali #thaali #jaipurigers #desifood #aloo #bainganbharta #papad #sabzi #lunchtime #foodtalkmumbai #foodpicsofinstagram #udaipurdiaries #northindianfood #ub #matarpaneer',
#  'तो कैसे है आप लोग 😂😂\n.\nशाम की चाय के साथ क्या नाश्ता करना पसंद करेंगे आप? जरा बताइए\n-लज़ीज़ Handvo\n-साबूदाना खिचड़ी\n- दही पूरी\n- दही कचोरी चाट..\n.\n.\n@maa_bhukh_lagi_hai\n.\nRepost पूछ कर करे....\n.\n.\n#sabudanakhichdi #sabudana #sago #dahipuri #puchka #udaipurite #jaipuri #desikhana #chaisutta #handvo #vegpizza #gujratifood #nashta #raita #zingyzest #trell #kachori #paneerrecipes #roti #udaipur #instaudaipur',
#  'तो कैसे है आप लोग 😂😂\n.\nशाम की चाय के साथ क्या नाश्ता करना पसंद करेंगे आप? जरा बताइए\n-लज़ीज़ Handvo\n-साबूदाना खिचड़ी\n- दही पूरी\n- दही कचोरी चाट..\n.\n.\n@maa_bhukh_lagi_hai\n.\nRepost पूछ कर करे....\n.\n.\n#sabudanakhichdi #sabudana #sago #dahipuri #puchka #udaipurite #jaipuri #desikhana #chaisutta #handvo #vegpizza #gujratifood #nashta #raita #zingyzest #trell #kachori #paneerrecipes #roti #udaipur #instaudaipur',
#  'आज की थाली - रसे वाली आलू टमाटर की सब्जी और गरमा गरम पूरियां....\nआलू पूरी,अरे इसका तो नाम लेने से ही सुकून मिल जाता है,और इसे खाने से तो jannat मिल जाती है....\n.\n.\nRepost ना करें\n.\n@maa_bhukh_lagi_hai\n.\n.\n#poori #aloopuri #halwapuri #thali #udaipurlove #jaipurfood #rajasthanifood #desifood #rajasthan #gharkakhana #bhindi #matarpaneer #dahibhalla #northindianfood #jainfood #lunchspecial #foodartblog #foodphotoaday #ub #udaipurlakecity #daal',
#  'आज की थाली - veg Biryani, दही और पुदीना गठिया.....\n.\nतो आप को क्या पसन्द veg biryani या Matar पुलाव\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#biryani #biryanilovers #pulao #indianthali #rajasthanithali #udaipurfashion #jaipur_diaries #desifood #khana #gathiya #roti #jaipurfashion #aamras #foodstagrams #matarpulao #lunchtime #foodtalkmumbai #foodphotografy #dahi #vegbiryani #khichdi #udaipurmonsoon #northindianthali #paneer #instafoodlover',
#  'आज की थाली - veg Biryani, दही और पुदीना गठिया.....\n.\nतो आप को क्या पसन्द veg biryani या Matar पुलाव\n.\n.\n@maa_bhukh_lagi_hai\n.\n.\n#biryani #biryanilovers #pulao #indianthali #rajasthanithali #udaipurfashion #jaipur_diaries #desifood #khana #gathiya #roti #jaipurfashion #aamras #foodstagrams #matarpulao #lunchtime #foodtalkmumbai #foodphotografy #dahi #vegbiryani #khichdi #udaipurmonsoon #northindianthali #paneer #instafoodlover',
#  'आज की थाली - मसालेदार भरवा बैंगन और ghee वाले परांठे और Green मिर्च के papad..\n.\nRecipe - भरवा बैंगन Recipe - भरवा बैंगन बनाने के लिए सबसे पहले आप बेसन लीजिए उसमें सौंफ, हींग, लाल मिर्च, हल्दी पाउडर, धनिया पाउडर, नमक, बारीक हरि मिर्ची, लहसुन का पेस्ट और बारीक कटा धनिया डाल दे। उस पर थोड़ा तेल डाल कर बैंगन मे भरने लायक मसाला बना दे।\n.\nअब यह मसला बैंगन मे भर दे और बैंगन को दो टुकड़े मे काट दे। अब एक आलू ले जिसे लंबा लंबा काट ले।अब एक कड़ाई मे तेल गरम करे जीरा, कटा हुआ लहसुन और हरि मिर्ची डाल दे उसके बाद आलू डाले थोड़ी देर पकने दें उस पर धनिया पाउडर, लाल मिर्च, हींग डाल कर पकने दे,थोड़ी देर बाद बैंगन डाल कर ढक दे, 5-10 बाद देखे... बैंगन पक जाएँगे...... बस तैयार हो गई भरवा बैंगन की सब्जी।\n.\n.\n#bharwabaingan #bainganbharta #parathas #paneerparatha #thaali #sweetudaipur #jaipurdairies #desighee #khana #rajasthan #gujratifood #rajmachawal #punjabifood #bhindi #raitarecipes #lunchtime🍴 #foodtalk #foods4thought #northindianfood #ub #papad',
#  'आज की थाली - मसालेदार भरवा बैंगन और ghee वाले परांठे और Green मिर्च के papad..\n.\nRecipe - भरवा बैंगन Recipe - भरवा बैंगन बनाने के लिए सबसे पहले आप बेसन लीजिए उसमें सौंफ, हींग, लाल मिर्च, हल्दी पाउडर, धनिया पाउडर, नमक, बारीक हरि मिर्ची, लहसुन का पेस्ट और बारीक कटा धनिया डाल दे। उस पर थोड़ा तेल डाल कर बैंगन मे भरने लायक मसाला बना दे।\n.\nअब यह मसला बैंगन मे भर दे और बैंगन को दो टुकड़े मे काट दे। अब एक आलू ले जिसे लंबा लंबा काट ले।अब एक कड़ाई मे तेल गरम करे जीरा, कटा हुआ लहसुन और हरि मिर्ची डाल दे उसके बाद आलू डाले थोड़ी देर पकने दें उस पर धनिया पाउडर, लाल मिर्च, हींग डाल कर पकने दे,थोड़ी देर बाद बैंगन डाल कर ढक दे, 5-10 बाद देखे... बैंगन पक जाएँगे...... बस तैयार हो गई भरवा बैंगन की सब्जी।\n.\n.\n#bharwabaingan #bainganbharta #parathas #paneerparatha #thaali #sweetudaipur #jaipurdairies #desighee #khana #rajasthan #gujratifood #rajmachawal #punjabifood #bhindi #raitarecipes #lunchtime🍴 #foodtalk #foods4thought #northindianfood #ub #papad',
#  'आज की थाली -Rava/सूजी इडली तड़के वाली \nआवश्यक सामग्री-\n1 कप RAVA/सूजी \nएक मोबाइल फोन \n3\\4 कप दही \nएक KIT-KAT\n3-4 गालियाँ मुझे देने के लिए . \nविधि- सबसे पहले Kit-kat लीजिए और उसका पैकेट खोल कर उसे साइड मे रख दीजिए, आप क्या समझे खानी हैं 😂😂। अब बर्तन लीजिए उसमें सूजी डाल दीजिए अब इसमें दही मिला लीजिए अब इसमे आधा चम्मच नमक डाल दीजिए. अरे क्या हुआ आज नमक शमक नहीं किया लगता है कोई नई डिश बनाते हुए बिगड़ गई है इसलिए chef वाला भूत उतर गया है अब kit kat लीजिए उसकी एक bite लीजिए और 4 sec तक उसका मज़ा लीजिए, मज़ा ले लिया हो तो एक बार फिर सूजी को अच्छे से मिला लीजिए ताकि नमक अच्छे से मिल जाए अब इसे 30min के लिए ढक कर रख दीजिए।\n. \nअब अपना phone लीजिए और मेरे इस page पर जितने photos है उन्हें like कर दीजिए जो आपने नहीं किए,मुझे पता है ये काम नहीं करोगे, आप तो tiktok खोल के बैठ जाओगे लेकिन like नहीं करोगे।हा साथ में kit-kat की bite जरूर लेते रहना अब 20 min बाद एक pan लीजिए उसमें तेल, ghee जो डालना है डालो मेरा कुछ ना जा रहा अब इसमे राई,कड़ी पत्ता, कुछ काजू, उड़द दाल,चना दाल डाल दीजिए और चलाते रहिए जब दाल का रंग बदल जाए तो गैस बंद कर दीजिए और इसे ठंडा होने दीजिए अब। अब सूजी के घोल को थोड़ा पानी डाल पतला कर दीजिए ज्यादा पतला ना करना, अब इसमे तड़का मिला दीजिए, अब इसमे आधा चम्मच खाने का सोडा मिला लीजिए,अच्छे से मिलाने के बाद इस घोल को इडली साँचे में डाल दीजिए घोल 70 प्रतिशत ही भरे साँचे मे ताकि इडली का आकार अच्छा आए। अब आप को थोड़ी टेंशन हो रही होगी कि ये इडली फूलेगी या नहीं, मेरे बारे मे ना सोचो की इसने recipe दी मेरा कुछ लेना देना नहीं सब किया आपने है फूले तो मुझे दुआ देना ना फूले तो गाली देना मुझे कौनसी लगने वाली है,ज्यादा tension ना लो आप kit-kat को खत्म करो और 14 min बाद गैस बंद कर देना आप की इडली फूल के तैयार होगई होंगी। इडली को थोड़ा ठंडा होने के बाद ही साँचे से बाहर निकालना ताकि इडली टूटे नहीं।\n.\n#idli #idlisambhar #ravaidli #indianthali #udaipurite #jaipurigers #southindianfood #southindiancuisine #maakhathkakhana #desikhana #gharkakhana #southindianbreakfast #sambar #upma #lunchspecials #foodholicmumbai #foodartblog #sabudanakhichdi #udaipurdairies #southindianthali #coconutchutney',
#  'आज की थाली - मसालेदार शिमला मिर्च और आलू की सब्जी, आम रस और ghee वाले परांठे..\n.\nक्या सिर्फ मेरा ही पराठा या आप का भी ये बोलता है कि "love me like you do" जब जब आप पराठा खाने बैठते है।\n.\n#mixveg #mixvegetable #shimlamirch #capsicum #thaali #udaipurlove #jaipur_diaries #rajasthanithali #khana #desighee #parathas #alooparatha #aamras #mixvegetables #northindianthali #lunchprep #f52home #ourfoodstories #udaipurcity #paneerbhurji #bharelamarcha',
#  'आज थाली की कि सजावट उतनी अच्छी नहीं लेकिन क्या करता आम रस और पूरी देख बस मन हो रहा था कब खा लूँ उसी जल्दी मे फोटो click किया....\nरस पूरी खाने के बाद भी इसके फोटो को ही देख कर इसे खाने की ईच्छा इतनी हो रही कि Caption भी ना लिख पाया 😂\n.\n.\n#poori #puri #mangolover #amras #udaipurblogger #jaipurfood #thali #rajasthanifood #aamraspuri #marathifood #desifood #gujratithali #maharashtrianfood #cholepuri #paneer #lunchtime #foodtalkmumbai #foodpicsofinstagram #udaipur #shreekhand #aloopuri',
#  'शाम की चाय के साथ कुछ तो चाहिए ही चाहिए सही कहाँ ना... तो पेश है "आलू गलौटी कबाब" जो मुहँ मे जाते ही गुल जाएं.\nऔर स्वाद का ऐसा धमाका करे जिसे आप कभी भूल ना पाएं..\n.\n.\n#alootikki #kababs #chaisutta #choletikki #udaipurfood #jaipuri #desikhana #indianthali #desinashta #khaman #upma #vadapav #chaat #paneerrecipes #nashta #lunchboxes #f52grams #foodphotoaday #udaipurphotography #tikkimasala #namkeen',
#  'आज की थाली - भरवा मिर्ची, मूँगदाल, घर का बना चिवड़ा और परांठे...\n.\nभरवा मिर्ची recipe -\nकितने लोगों के लिए- पूरी family के लिए,अब एक के लिए तो बनोगे नहीं आप\n.\nबनाने मे समय - जितना आप को लगाना हो\n.\nआवश्यक सामग्री\nPyar - ये अगर है आप की recipe मे तो नमक ज्यादा हो या कम family इसे खा कर खुश हो जाएगी.\nविधि- एक pan लीजिए उसमें आधा चम्मच सौंफ डालिए और फिर उस पर बेसन डाल दीजिए। मिर्ची मे भरने के लिया जितना चाहिए उतना। अब इसे सेख लीजिए, ध्यान रखना जल ना जाए। अब इसे एक प्लेट मे निकाल लीजिए और ठंडा होने दीजिए।ठंडा होने के बाद इसमे लाल मिर्च एक चम्मच, हल्दी पाउडर, धनिया पाउडर थोड़ा हींग डाल दीजिए।अब वो कोने मे पड़ा नमक का डिब्बा लीजिए और डाल दीजिए अरे डिब्बा नहीं डालना नमक डालना है बस डालते समय ध्यान रखना खुद ने भी खाना है। अब इसमे हरि मिर्ची बारीक, हरा धनिया काट लीजिए अब थोड़ा तेल डालिए ताकि एक साथ बंध जाए अब इसमे निम्बु का रस डालिए और मिला लीजिए। अब एक बार taste कर लीजिए, खट्टा कम है ना हाँ मुझे भी लगा तो डाल दीजिए निम्बु का रस, अब मिर्च मे कट लगा कर ये मसाला भर दीजिए हाँ चाहें तो मिर्ची के अंदर के बीज निकाल लेना ताकि कम तीखा लगे अब बस एक pan लेकर उसमे तेल डालिए फिर उसमे जीरा, मेथी, लहसुन डाल कर पकने दीजिए और फिर भरी हुई मिर्ची डाल दीजिए और पकने दीजिए 12-15\nmin, बस फिर तैयार मिर्ची।\nहाँ एक तो मिर्ची को धीरे धीरे हिलाना pan मे अपनी सास को याद कर के हिलाने की जरूरत नहीं और अगर ये डर रहता है कि हमारी मिर्ची तो जल जाती है तो कुकर मे बनाओ या थोड़ी देर पकने के बाद pan के नीचे Tawa रख दो। फिर भी जल जाए तो समझ लेना बहुत पाप किए है 😂 😂 😂 😂\n.\n.\n#paratha #lacchaparatha #bhindimasala #bharelamarcha #thaali #udaipurblogger #rajasthanithali #jaipurigers #rajasthani #daal #desikhana #bharwabaingan #daltadka #matarpaneer #raita #northindianfood #lunchspecials #foodholicmumbai #foodartblog #udaipurblog #bharelivangi',
#  'आज की थाली - दाल-बाटी\nये राजस्थानी बाटी का ही एक रूप है, जिसे तरमा बाटी कहा जाता है, तरमा मतलब ghee मे तली हुई बाटी...\nइसे कुछ लोग bafla बाटी भी बोलते है लेकिन ये bafla नहीं bafla Bati मध्यप्रदेश के मालवा इलाके मे ज्यादा बनाई जाती है और उसको बनाने का तरीका थोड़ा अलग है.\nये बाटी उसने सबसे पहले बनाई होगी जिसे ज्यादा Ghee नहीं खाना क्योंकि इसमे कम ghee use होता बाकि बाटी की तुलना में।\n.\n.\n#dalbati #dalbatichurma #dalbatilovers #thali #udaipuri #jaipur_diaries #rajasthanifood #rajasthan #churma #desighee #marwadifood #indorizayka #khana #lunchtime #foodtalkmumbai #foodpicsofinstagram #northindianthali #udaipurblog #indorifood #littichokha #mithaibox',
#  'Roti पोहा recipe - जरूरी नहीं कि रात की बची हुई रोटी से ही आप ये बनाए, मे तो मम्मी को पहले ही बोल देता आज कुछ रोटी ज्यादा बनाना roti poha खाना है.....\n.\nRecipe - video देख लो समझ आजाये गा। हर चीज़ लिखनी जरूरी नहीं 😂\n.\n.\n#roti #poha #rotipoha #udaipurfoodies #nashta #leftoverrecipes #kitchendiaries #jaipurfoodblogger #chapati #simplisticfood #eeeeeats #homecooking #homecooked #foodspread #mumbaifoodblogger #instafoodie #therawtextures #foodtalkindia #20likes #upma #kandapoha',
# ...
#  'जब एक राजस्थानी के पैट मे कुछ स्वादिष्ट और मसालेदार खाने के सुनामी उठती हैं, तो आप जानते हैं कि वो किस पर आक्रमण करता है? . क्योंकि खाने की craving जब surgical strike krti है उसके पैट में, तो उसके दिमाग और आत्मा को "बेसन गट्टे" और फूलका थाली से बेहतर कोई थाली संतुष्ट नहीं कर सकती। . सबसे पहले,वो बस उस थाली को देखता हैं। उसके लिए वो थाली किसी बाकी खाने की थाली जैसी नहीं है। वो थाली जुनून, इच्छा और लालच से भरी होती है। वो सिर्फ Besan Gatte की सब्जी को निहारता हैं, और सोचता है कि वो इसे कैसे खाएं। फिर,वो उसे प्यार से स्पर्श करता है। वो स्पर्श उसकी इंद्रियों को शांत करती है,और उसके मन को छेड़ने का प्रयास करती है। . फूलका roti की एक bite ,सही आकार की , Besan Gatte की सब्जी के साथ। उसके मुँह मे taste का एक बड़ा धमाका करती हैं। पहले कुछ hot फिर spicy  और फिर बेसन गट्टे की softness का अनुभव होता है।और जब वो उसके गले से नीचे जाता है तब जाकर उसकी आत्मा को संतुष्टि मिलती है। 😂 😂 😂 😂 😂 . "Love शास्त्र" मे इसको को ही प्यार का एहसास कहा गया है 😂 😂 ..#besangatte #gatte #besangattekisabji #udaipur #rajasthani #rajasthanifood #rajasthanifood😍 #kota #jodhpur #jaipur #traditional #rajasthani_style #rajasthanijewellery #thalifood #bite #freshfood #instafood #foodart #rajasthan #northindianthali #southindianthali #dalbati #mirchiwada #marwari #foodinstagram #sabji #foodcoma',
#  'North India के बच्चों के लिए "Kadi - chawal" एक ऐसी dish है, जिसे वो जब भी खाते है तो उनकी आँखो के सामने उनकी बचपन की यादें आजाती हैं। इससे कोई फ़र्क़ नहीं पड़ता कि वो बच्चे कीस तरह बड़े होते है और दुनिया के किस कौने मे अपना जीवन जीते है।पर कड़ी चावल की प्लेट के लिए उनके अंदर का भूक्कड़ हमेशा जिंदा रहता है।. - जब कड़ी के साथ रोटी थाली मे परोसी जाती है ना मुझे, तब उसे देख लगता कि ये बहुत बड़ा पाप है, क्योंकि कड़ी सिर्फ चावल के लिए बनी है। दुनिया मे कुछ भी ऐसा नहीं जिसका Taste इन दोनों जैसा हो। वो दोनों एक दूसरे के बिना अधूरे है, जैसे - सलमान की movie shirt उतारे बिना , राम (रणवीर) अपनी लीला (दीपिका)के बिना , मोदी का भाषण फेंके बिना, राहुल का भाषण कॉमेडी के बिना और राज अपनी सिमरन के बिना 😂😂😂😂😂."शास्त्रो" में इसे ही सच्चा प्यार कहा गया है।.#kadichawal #chawal #udaipurfood #udaipur #thalifood #rajasthan #panjab #kashmiri #delhi_foodie #rajasthanifood😍 #northindianfood #foodposts #foodclicks #pakoda #lunchspecials #rajmachawal #foodcoma #eat #foodstagrams #hungry #f52gramsfoodpics #soulfoodies #freshfood #pakodakadi #fulka #jaipurfood #kota',
#  '❤️मुझे ऐसे कई lunch time याद है जहाँ माँ ने मुझे यह बताकर चौंका दिया था कि आज lunch में "आलू के पराठे" बनाए है। और फिर मैं इसे lunch में खाने के लिए और साथ मे बचे हुए मसाले के फिर से Evening में पराठे खाने के सपने देखता 😂😂ज्यादातर माँओं की तरह, मेरी माँ को भी पता था कि बच्चे के दिल का रास्ता वास्तव में आलू पराठे की एक प्लेट से जाता है। आलू पराठे की उस थाली ने मेरे घर मेरी कई शैतानियों से पड़ने वाली पापा की डांट से बचा लिया । क्योंकि पापा को भी बहुत पसंद हैं पराठे, पराठे की थाली देख पापा का गुस्सा भी शांत हो जाता 😂 😂 😂 .मुँह मे जो flavours का धमाका आलू पराठे को दही के साथ खाने से होता है उससे पता चलता है कि कितनी शिद्दत से उस आलू पराठे को बनाया गया है। आलू पराठा एक ऎसी dish है,जिसकी recipe पूरी family में दौड़ती है, दादी से माँ, माँ से बहन, या नानी से माँ, माँ से बहु और सभी बच्चे यही कहते है कि मेरी "माँ" ❤️ सबसे best आलू पराठे बनाती है। ❤️ 😂 😂.#alooparatha #alooparathe #desighee #desikhana #foodphoto #lunchspecials #maakhathkakhana #udaipur #rajasthani #punjabifood #northindianfood #thalifood #jaipur #pickle #aachar #papa #flavoursofindia #dahi #papad #delhifood #soulfoods #parathay #aloopyazparatha #aloopuri #alookulcha #udaipurfood #recipesforselflove',
#  'जिन्दगी मे,Feeling bored? तो चाय किसी मुद्दे पे बहस करनी हो तो चायOffice मे अपने boss की बातों से bore हो रहे तो mood fresh करने के लिए चायइस भयंकर सर्दी से लड़ना है तो ek cup चायDost, जिन्दगी का साथी और हमदम ये सब Chai के synonymous है जिसमे emotion है एक चाय प्रेमी का.... लोगों को coffee बहुत पसंद लेकिन लेकिन मुझे और बहुत से भारतीयों के लिए चाय के एक cup से accha कुछ नहीं..... और साथ में ये थाली हो तो बस और क्या चाहिए 😂 😂 😂.#chai #nastha #tea_ #coffeeaddicts #teaaddiction #chailovers #murmura #bhel #biscuits🍪 #aloosev #orangecandy #udaipur #kota #rajasthani #northindian #aloochips #vrat #f52gramsfoodpics #lunchspecials #par #teatime #udaipurfood #delhifood #foodcoma #namkin #foodstyling #jaipur',
#  '-जब मेरे सामने ये थाली आयी जिसमे एक कोने मे khaman, एक कोने मे कचोरी और थाली के आधे हिस्से में फाफड़ा पड़ा था।मेने FAFDA से पूछा कैसा लगता है जब, तुम्हारे नाम से गुजरात और गुजराती लोगों को जाना जाता है।Fafda मुझसे बोलता है-AT कभी कभी अपुन को लगता है कि इन Gujju लोगों का अपुन ही भगवान है। ये khaman भी अपना कुछ नहीं बिगाड़ सकता, क्योंकि अपुन इससे भी ऊपर..... इन Gujju लोगो का सर्वशक्तिशाली एक लोता भगवान अपनू ही है। FAFDA GAITONDE है मैं 😂😂😂.#fafda #khaman #khamani #khamandhokla #dhoklas #dhoklarecipe #jalebifafda #jalebis #nastha #udaipur #kachori #kachorichaat #gujratifood #gujratithali😋 #foodphotoshoot #ahemdabadi #thalifood #lunchtime😋 #f52grams #foodstagrams #indianstreetfood #foodloversindia #jaipur #gujratitradition #surat #northindianfood #desikhana',
#  'JALEBI - इसके नाम से ही शाही अंदाज झलकता है। इसे देख जो हमारे दिल में उसे खाने की इच्छा उमड़ती हैं, उसे ही "love at first Sight" बोलते हैं।.आजकल कुछ विदेशी चीज़े जैसे brownies, cup cacke हर शादी party मे मिल जाते है, लेकिन आज भी अगर जलेबी ना हो party में तो ऐसा लगता कुछ अधूरा सा है।.जब कोई भी जलेबी की first bite लेता है तो उसकी आँखे बंद हो जाती, और मुँह मे जाने के बाद जब Taste का धमाका उसके मुँह मे होता, तो जो Reaction उसके face पे आता है, तो लगता उसे उसका प्यार मिल गया 😂 😂. जब जलेबी को गर्म खाया जाता है तो वो बहुत शानदार लगती है But उतनी ही स्वादिष्ट ठंडी खाने पर भी लगती है। वैसे हम INDIANS को गर्म ठंडे से कोई फ़र्क़ ना पड़ता हमे तो बस स्वाद से मतलब है। "pyar to aise hee hota hai boss".....#jalebi #jalebilover #jalebifafda #dudhjalebi #deshighee #dessertpic #udaipur #rajasthanifood #northindianfood #pohajalebi #jaipur #ghevar #sweetooth #photographylover #thalifood #desikhana #f52gramsfoodpic #delhifoods #rajasthani_style #mithaibox #mitha #ladoo #indorifood #indianstreetfoods #udaipurfood #foodphotoshoot #lunchtime😋',
#  'If there\'s one real, genuine foodporn moment, it involves enjoying a sizable amount of "Dal-Bati".."Repost" karne se pahle puch le 🙏.Happy Republic Day .#dalbatichurma #dalbati #dalbatilovers #rajasthanifood😍 #rajasthanithali #rajasthan #udaipur #jodhpur #kota #jaipurfood #foodphotoshoot #desighee #desikhana #f52grams #foodstagrams #papad #rajasthani_style #rajasthanifood #thalifood #lunchtime😋 #udaipurfood #jaipur #ghevar #northindianfood #photographylover #littichokha #indorifood',
#  '"खाने की जन्नत से अलग कोईजन्नत नहीं इस जहाँ मे". और खाना "माँ" के हाथ को तो..... बात ही अलग है। .#kadichawal #chawal #dalchawal #udaipurfood #udaipur #punjab #kashmiri #rajasthanifood😍 #rajasthani #pakodakadi #fulka #jaipurfood #foodphotoshoot #lunchtime😋 #thalifood #foodloversindia #delhifoods #northindianfood #northindianthali #foodcoma #hungry #eat #f52gramsfoodpic #desikhana #rajasthanithali #kadikachori #foodstagrams',
#  'कचोरी" definitely भारत के सबसे मनोरम खाद्य पदार्थों में से एक है। जो भी हो, व्यक्ति को खाने की पूजा करने की आवश्यकता है। वह नहीं जानता होगा, लेकिन जब उसने पहली बार सभी सही मसाले दाल मे मिलाए तो वो एक भरी-पूरी सुंदरता को उकेर रहा था। आटा गूंध कर उसमे जब दाल भर कर भूरे रंग की एक भव्य छाया में तला, तो वो दुनिया की एक सुंदर चीज़ की सुंदरता को पूर्ण कर रहा था।उसकी कड़ी मेहनत का अंतिम परिणाम और उसकी भावुक दृढ़ता का नतीजा कुछ ऐसा था जो कई लाखों लोगों के लिए समर्पित था। . क्योंकि कचोरी सिर्फ खाना नहीं है। यह मनुष्य की सबसे बड़ी उपलब्धियों में से एक है। और निश्चित रूप से उनके सबसे सुखद अनुभवों में से एक है।. यदि आपने कभी इसे खाया होगा , तो आपको पता होगा कि मैं किस बारे में बात कर रहा हूं।.कचोरी की एक खाशियत है कि वो सिर्फ 2 चीज़ों तक सीमित नहीं.....उसके साथ प्याज, नमकीन और चटनी होती है, चटनी मे डूबी हुई कचोरी ऊपर से प्याज और नमकीन की एक bite आपको जन्नत की शेर करा देती है।.पाकशास्त्र मे इसे ही पेट - पूजा कहा गया है 😂 😂 😂 😂 😂.#kachoris #kachorichaat #kachori #kachorisabzi#samosa #rajasthanifood😍 #jodhpur #jaipur #jaipurfood #kota #udaipur #rajasthani_style #rajasthani #pyazkachori #dahikachori #foodphotoshoot #instaposts #instafood #foodart #bikaneri #nastha #foodcoma #photographylover #northindianfood #indorifoodie #namkin #kadikachori',
#  'MILK CAKE मेरे favourite desserts की list मे First place पे आता है। अखिर मेरे Taste के exam मे top जो किया milk cake ने। milk cake सिर्फ एक मिठाई नहीं है, एक भावाना है, प्यार है त्योहार है।.मुझे मेरे बचपन का एक भी ऐसा दिन नहीं याद की जब मेरे घर milk cake मिठाई का डिब्बा ना हो। मेरी दादी और मुझे हम दोनों को बहुत पसंद. इसलिए पापा ले ही आते थे, डिब्बा ख़त्म होने से पहले।.जब त्योहार आते है रक्षाबंधन, होली, दीवाली तो बहुत सी अलग-अलग तरह की मिठाई घर आती है जिनके नाम मुझे याद नहीं पर उनके साथ आता milk cake वो मुझे याद 😂😂त्योहार बड़ा हो या छोटा milk cake के बिना सब अधूरा। .जब मे किसी रेस्टोरेंट में जाता हूँ और वहा के menu मे milk cake ना हो तो मैनेजर को बोल कर आता हूँ कि milk cake भी होना चाहिए मैन्यू मे हा ये अलग बात सब मेरी बात नहीं मानते 😂😂😂last year मेरे friend की शादी थी तो उसे तो पहले ही बोल दिया था milk cake na रखा खाने में तो मेने नहीं आना तेरी शादी में😂😂😂.... ये थी कुछ यादे मेरी और milk cake की aap भी share kre comments me..... 🙏.#milkcake #mithai #bhindi#indiancuisine #maharashtrianfood #mithaibox #udaipur #rajasthani #foodphotoshoot #desighee #desikhana #rajasthanifood😍 #alwar #kajukatli #jaipurfood #thalifood #gulabjamun #ghevar #northindianfood #photographylover #rajasthanithali #marwadifood #udaipurfood #kota #cake #halwa #halwapuri',
#  'अगर वो (she) अंगूर है, और तुम संतरा (Orange) तो इस अन्तर को Celebrite करो अच्छा सा "fruit Salad" बनाओ. प्यार सिर्फ एक जैसा होने मे नही प्यार तो एक दूसरे के साथ sweet और acche से रहने में है।.#orange #oranges #santra #angoor #fruit #fruitsalad #healthyfoodlovers #udaipur #nagpurorange #photographylover #nagpur #rajasthanifood😍 #jhalawar #paneerbuttermasala #foodloversindia #choclateday #foodloves #foodstagrams #healtybreakfast #grapes #juice #orangejuice #aam #mangojuice #aamras #fruitchaat #guava',
#  '"Evening वाली छोटी भूख"मेरे लिए पूरे दिन में सबसे best time ये evining time होता है, जिसे Tea Time भी bol सकते है। मे पूरे दिन iskat wait करता हूं, कि कब 4 बजे और मे अपनी छोटी सी भूख को शांत करने के लिए कुछ खाऊ।.मेरे घर में 4 (evening) बजे का time कुछ spacial होता है, मेरे घर 4 बजे चाय बनती है और उसके साथ कुछ ना कुछ खाने के लिए बनता है कभी समोसा, कचोरी, कभी पकोड़े या कभी साबूदाना खिचड़ी और भी बहुत कुछ। बचपन मे अगर मे खेलने भी जाता तो 4 बजे तो घर पे आजाता क्योंकि मम्मी कुछ Spacial बनाती तो उसके लिए game बीच मे छोड कर भी आजाता, हा खा कर फिर चला जाता खेलने 😂😂. मेरे घर में कुछ important बात करने का time भी यही है, "चाय पे चर्चा" का time। .बचपन की इसी आदत की वजह से आज भी 4 बजे मेरा मन कही नहीं लगता, OFFICE मे भी 4 बजे कुछ काम करने का मन नहीं होता, जब तक चाय और कुछ snacks ना खाने को मिल जाए। 😂 😂 😂 😂. Ha इस आदत की वजह से बहुत लोगों को मुझसे problem है पर मे Happy इससे... "Chulhe" में जाए वो लोग मुझे क्या 😂😂.आप भी share करे अपनी "Evening वाली भूख" की story... Comment में।.#chai #maakhathkakhana #teatimes #udaipur #jaipur #rajasthanifood😍 #rajasthanithali #jaipurfood #kota #jodhpur #thalifood #sabudana #sabudanakhichdi #vrat #vratkakhana #eveningsnacks #nashta #foodphotoshoot #desikhana #namkin #foodstagram #udaipurfood #rajasthanithali #khichdi #khana #northindianfood #homemade',
#  'किसी ने सही कहा है, "नमक की तरह हो गयी है जिन्दगी लोग स्वादानुसार इस्तेमाल करते हैं" . दुनिया मे शायद ही मेरे अलावा कोई नमक का इतना Jabra FAN होगा। हा मेरी यह बात पड़ कर बहुत से लोग सोचने पे मजबूर हुए होंगे कि "नमक का fan"! हा हूँ मे नमक का fan क्या करू प्यार है मुझे नमक से। जब तक दिन मे 3-4 बार touch ना कर लूँ ना मे नमक को मेरा दिन ना निकलता। नहीं करता touch तो नमक मुझे अपने पास बुलाता है और बोलता है "zara zara touch me touch me touch me" 😂 😂.मेरा नमक के साथ ऐसा रिश्ता है कि खाना Taste करने से पहले ही मुझे नमक डालाना पड़ता है क्या karu प्यार है ना नमक से, ha इसी आदत की वजह से कभी कभी नमक का प्यार ज्यादा हो जाता थोड़ा ज्यादा ही "नमकीन" हो जाता 😂 😂 😂 😂.मुझे अलग अलग brand\'s के नमक taste करने की बड़ी आदत है तो करता रहता हूँ। इसी के चलते @lunn_salt ने मुझे अपना Desert नमक भेजा जो मुझे अच्छा लगा, सबसे अच्छी बात इस नमक की ये है कि इसका Harvest process Environmentally friendly है, sun-dried, hand-Harvest prosses की वजह से ये Industrial pollution से बहुत दूर है और pure है कोई मिलावट नहीं और मेरे "राजस्थान" का नमक है। .आप भी एक बार जरुर try करे @lunn_salt आप इसे amazon से भी order कर सकते है।.#gharkakhana #maakhathkakhana #thalifood #aloomatar #rajasthanifood😍 #rajasthanithali #udaipur #kota #jaipurfood #jaipur #jodhpur #udaipurfood #desikhana #desighee #northindianfood #foodphoto #ladoo #rajasthani #dalbati #foodstagram #foodofinstagram #northindianthali #foodphotoshoot #lunch #parathay #alooparatha #namak',
#  '"बेसन गट्टे की सब्जी" Rajasthani Cuisine की एक महत्वपूर्ण dish है, इसके बिना राजस्थानी खाना अधूरा है, ये dish आप को हर hotel की Rajasthani Thali मे मिलेगी। वैसे तो इसे रोटी के साथ खाया जाता है पर राजस्थानी बाटी के साथ खाने का भी अलग मज़ा है।.-cuisine क्या है?.. आज cuisine के बारे में बात हो रही तो कुछ चीज़े बताना चाहता हूं। भारत के किसी भी state के मंदिरों, गुरुद्वारों और मस्जिदों मे जो खाना बनाया जाता है जिसे लंगर, भंडारा भी कहा जाता है इसमे बनने वाला खाना cuisine नहीं है ये large quantity मे बना खाना है जो श्रद्धालुओं को प्रसाद के रूप में दिया जाता है। cuisine असल मे पूरा system है खाने का, cuision का devlepment एक long period of time मे हुआ, एक feudal practice है, जो राजा महाराजाओं के time मे हुआ। .अब पुराने time मे राजाओं के पास कुछ काम तो था नहीं क्योंकि हजारों किसान मजदूर उनके लिए काम कर रहे थे, अनाज पैदा कर रहे थे उनके tax से आप राज कर रहे है । तो राजा बैठे - बैठे अपने रसोइएं या खानसामा को बुला कर बोलते कि आज बिरयानी मे थोड़ी इलायची डाल के देखना, चलो इलायची अगली बार डालना इस बार केसर डाल कर बनाओ।ये सब feudal time मे ही possible है।इस तरह हर dish मे कुछ नया करने से किसी भी जगह की cuisine का निर्माण हुआ है।.बेसन गट्टे की सब्जी  Rajasthan की Royal Dish है जो हर राजस्थानी को पसंद.....#gattekisabzi #besangatte #rajasthanifood😍 #rajasthanithali #jaipur #udaipur #kota #jodhpur #udaipurfood #jaipurfood #rajasthani #gharkakhana #maakhathkakhana #thalifood #rajasthan #foodart #northindianfood #dalbati #ladoo #desikhana #desighee #udaipurtimes #rotisabji #hungry #aloopuri #ghevar #foodloversindia',
#  'Simple "गुजराती थाली" जो रोज़ एक गुजराती घर में बनती है, रोटीली/फूलका, सब्जी, दाल, थोड़ा फरसाण और मीठा (केसर बर्फी)।.गुजराती खाने को लेकर लोगों ने एक मानसिकता बना ली है कि, पूरा गुजराती खाना मीठा होता है, हा गुजराती खाने की कुछ चीज़े मीठी होती है पर पूरा खाना मीठा नहीं होता। लोगों को लगता सब्जी, पराठा, दाल सब कुछ मीठा होता है।.पुराने समय में गुजरात,महाराष्ट्र,राजस्थान में जब घर का आदमी पूरे दिन काम कर के आता था क्योंकि पहले तो Air conditioning वाले ऑफिस होते थे नहीं, पैसा कमाने का साधन खेती ही थी तो जब वो पूरे दिन थक कर घर आता या कोई मेहमान आता क्योंकि वो चल कर आते थे कुछ साधन तो था नहीं ना। तो उसे सबसे पहले पानी के साथ गुड़ दिया जाता था। इससे body मे energy आजाती थी। तो अब हुआ ऐसा कि मेरे जैसा एक होशियार होगा उसने सोचा ये बार बार तो गुड़ देना पूरे दिन possible है नहीं तो उसने दाल में गुड़ मिला दिया जो लोगों को अच्छा भी लगा और energy के लिए जो चाहिए गुड़ वो भी आगया। इसलिए दाल मीठी बनाई जाती सब्जी मे नही डाला जाता कुछ मीठा ना रोटी ना चावल मे।.इसलिए खाओ गुजराती खाना, वैसे गुजराती language ज्यादा मीठी होती, गाली भी दो तो भी मीठी लगती 😂😂😂😂😂.#gujratifood #gharkakhana #maakhathkakhana #thalifood #kesarbarfi #desikhana #desighee #gujraticuisine #gujratithali #udaipur #rajasthanifood😍 #northindianfood #farsan #ladoo #roti #khana #jaipur #kota #jaipurfood #rajasthani #jodhpur #udaipurfood #ahemdabadfoodie #foodart #hungry #palakaloo #foodlovers']

# %% [markdown]
# ## Full code test

# %%
#Frame pre-processing function
def process(array,avoidwords):
    hashes = len(re.findall(r'#',str(captions))) #counting hashtags
    text = re.sub(r'\[[0-9]*\]',' ',str(array))  #Remove Numbers
    text = re.sub("^\d+\s|\s\d+\s|\s\d+$", " ", text) # Remove nums
    text = re.sub(r'\s+',' ',text)  #Remove extra space
    text = re.sub(r"[^a-zA-Z0-9]+",' ',text)  #Remove special characters
    text = text.lower()  #Lower case all
    text = nltk.sent_tokenize(text)  #Tokenize to sentences 
    keywords = [nltk.word_tokenize(sentence) for sentence in text]
    raw_cap = len(keywords[0]) # Total number of words in caption
    stop_words = stopwords.words('english')
    stop_words.extend(avoidwords)
    for i in range(len(keywords)):
        keywords[i] = [word for word in keywords[i] if word not in stop_words]
    genuinity_percent = (raw_cap-hashes)*100/raw_cap
    return keywords,genuinity_percent

def flat(array):     # 2D array reduction
    flatten_list = [j for sub in array for j in sub] 
    flatten_list = list(chain.from_iterable(flatten_list))
    return flatten_list

def soft_flat(array):     # 2D array reduction
    flatten_list = [j for sub in array for j in sub] 
    return flatten_list


# normalize() -> given an array, converts to 1/0, top int(pos) will be 1
def normalize(keys, pos =3):  
    ax = [i for i in keys]
    temp = [i for i in keys]
    temp.sort()
    temp = temp[-pos:]
    for x in temp:
        ax[keys.index(x)] = 1
    for x in range(len(ax)):
        if ax[x] != 1:
            ax[x] = 0
    return ax

def normalizeSD(keys, thre =3):    # Given score array return shortlisted cats in given threshold
    ax = deviation(keys)
    ax = dev_shortlist(ax,thre)
    return ax

# compute() => category[] to be called outside
def compute(caption,category,top =3):
    ar = []
    score = []

    # Code to get frequency distribution and unique keywords array
    keywords = []
    caption_freq = []
    counts = Counter(caption)
    if len(counts) > 0:
        labels, values = zip(*counts.items())
        ## sort your values in descending order
        indSort = np.argsort(values)[::-1]
        ## rearrange your data
        keywords = np.array(labels)[indSort]  # Label
        caption_freq = np.array(values)[indSort]  # Values
    
    # Detect words not in Google Dict | Put freq = 0
    for x in keywords:
        try:
            restConst = w.similarity(x,'something')
        except KeyError:
            caption_freq[np.where(keywords == x)] = 0
        
    #Google similaity function
    for x in category:
        empty = []
        for y in keywords:
            try:
                empty.append(w.similarity(x,y))
            except:
                empty.append(0)
        ar.append(empty)
    
    # Store the similarity values in dataframe
    frame = pd.DataFrame()
    frame = pd.DataFrame(ar, columns = keywords)
  
    #Normalize | top select
    for key in frame.columns:
        frame[key] = normalizeSD(frame[key].tolist(),top)
    
    # Multiply with frequency
    for row in range(len(frame)):
        frame.values[row] = [i*j for i,j in zip(frame.values[row],caption_freq)]
    # Sum the values => Score
    for row in range(len(frame)):
        score.append(sum(frame.values[row]))
    
    frame['category'] = category
    frame['Scores'] = score
    return frame,keywords[:20]

def deviation(array):
    mu = max(array)
    l = len(array)
    ar = []
    for x in range(l):
        ar.append(math.sqrt((array[x]-mu)**2)/l)
    total = sum(ar)
    for x in range(l):
        if total != 0:
            ar[x] = (ar[x]/total)*100
    return ar

def mean_deviation(array):
    l = len(array)
    mu = sum(array)/l
    ar = []
    for x in range(l):
        ar.append(math.sqrt((array[x]-mu)**2)/l)
    total = sum(ar)
    for x in range(l):
        if total != 0:
            ar[x] = (ar[x]/total)*100
    return ar

def dev_shortlist(dev_array,thre = 2):  # Shortlist using threshold from deviation array | return array in 1/0
    final_cat = [0]*len(dev_array)
    for i in range(len(dev_array)):
        if dev_array[i] <=thre:
            final_cat[i] = 1
    return final_cat

def get_row_pscore(col_name,f1,i,f2,genuinity_score,top_keywords, scoreType):  # f1-mainframe | f2-frame
    ud = f1.loc[i,'id']
    ul = f1.loc[i,'url']
    row_in_array = [ud,ul]
    score_array = f2[scoreType].tolist()
    empty_score = [0]*(len(col_name)-len(score_array)-4)
    score_array.extend(empty_score)
    row_in_array.extend(score_array)
    row_in_array.append(genuinity_score)
    row_in_array.extend([top_keywords])
    zip_it = zip(col_name,row_in_array)
    convert_to_dict = dict(zip_it)
    return convert_to_dict

# To make data in 
# DB format | API post 
def to_dict_api(percentages,categories,top_keywords,frame,i): #frame and i to get id
    mydict = {}
    cat_array =[]
    empty_percent = [0]*(len(categories)-len(percentages))
    percent_array = [y for y in percentages]
    percent_array.extend(empty_percent)
    mydict['user_id'] = frame.loc[i,'id']
    mydict['keywords'] = json.dumps(top_keywords.tolist())
    for j in range(len(categories)):
        cat_array.append({'tag':categories[j],'percentage':percent_array[j]})
    mydict['categories'] = json.dumps(cat_array)
    return mydict

categories = ['food', 'fashion', 'makeup', 'beauty', 'lifestyle','luxury', 'traveler','photography','fitness','sports','gaming', 'entertainment', 'technology','investment','education', 'animal', 'health']
# This required to run some function
col_name = ['user_id','url','Food','Fashion', 'Makeup', 'Beauty', 'Lifestyle','Luxury', 'Travel','Photography','Fitness','Sports','Gaming', 'Entertainment', 'Gadgets & Tech','Finance','Education', 'Animal/Pet', 'Health','Art', 'Self Improvement', 'Parenting', 'Books', 'genuinity_score','top keywords']
API_categories = ['Food','Fashion', 'Makeup', 'Beauty', 'Lifestyle','Luxury', 'Travel','Photography','Fitness','Sports','Gaming', 'Entertainment', 'Gadgets & Tech','Finance','Education', 'Animal/Pet', 'Health','Art', 'Self Improvement', 'Parenting', 'Books']

# %%
tic = time.perf_counter()
x = requests.get('http://44.229.68.155/insta_users/get_uncategorized_accounts?limit=10&current_id=15000', headers={'Authorization': 'Token ruor7REQi9KJz6wIQKDXvwtt'})
status = x.status_code
data = x.json()
df = pd.DataFrame(data['users'])
pages = 0
idsdone = 0
txt = "Done {} pages, the last_id is {} and time taken {} seconds"

while(len(data['users']) !=0 and pages<1):
    try:
        new_tic = time.perf_counter()
        if(status != 200):
            raise Exception("GET request error: {}".format(status))
        dfnew = pd.DataFrame(columns=['id','handle','name','url','gender','country','captions','bio'], data = df[['id','handle','name','url','gender','country','captions','bio']].values)
        last_id = dfnew['id'].iloc[-1]
        # Fresh dataframe
        profile_percentages =  pd.DataFrame(columns = col_name)
        
        # Main Categorization # 
        for i in range(len(dfnew)):

            try:
                #Store userid | caption | total posts
                userid = dfnew['id'].iloc[i]
                captions = dfnew['captions'].iloc[i]
                bio = dfnew['bio'].iloc[i]
                total_posts = len(captions)

                # Fresh dataframe
                profile_percentages =  pd.DataFrame(columns = ['user_id','url','food', 'fashion', 'makeup', 'beauty', 'lifestyle','luxury', 'travel', 'photography','fitness','sports','gaming', 'entertainment', 'technology','investment','education', 'animal','health', 'parenting','top keywords'])

                # Words which mostly occurs in insta post and we want to avoid considering them for the sake of accuracy of results
                avoidwords = ['verified','none','follow','like']

                #Converting to keywords
                captions,genuinity_score = process(captions,avoidwords)
                caption_array = captions[0]
                bio,ignore_this_var = process(bio,avoidwords)
                bio_array = bio[0]
                # Punishing accounts which has less than 3 words in caption
                if len(caption_array) < 3*(total_posts):
                    raise Exception("Too less words for categorization")

                #Temporary array i-> interim
                icaption_array = [z for z in caption_array]
                ibio_array = [z for z in bio_array]
                # Removing words not in dictionary also single characters
                discarded_words = []
                discarded_bio_words = []
                for x in caption_array:
                    try:
                        checkword = w.similarity(x,'something') #Check word if exist in googlenews
                        if len(x) <2: #Removing single character
                            icaption_array.pop(icaption_array.index(x))
                    except KeyError:
                        discarded_words.append(icaption_array.pop(icaption_array.index(x)))
                for x in bio_array:
                    try:
                        checkword = w.similarity(x,'something') #Check word if exist in googlenews
                        if len(x) <2: #Removing single character
                            ibio_array.pop(ibio_array.index(x))
                    except KeyError:
                        discarded_bio_words.append(ibio_array.pop(ibio_array.index(x)))
                #Restore Array
                caption_array = [z for z in icaption_array]
                bio_array = [z for z in ibio_array]
                # Check similarity in discarded words
                discard_word_scores = [0]*len(categories)
                discard_bio_word_scores = [0]*len(categories)
                for x_word in discarded_words:
                    for the_category in categories:
                        if the_category in x_word:
                            discard_word_scores[categories.index(the_category)] = 1 + discard_word_scores[categories.index(the_category)]
                for x_word in discarded_bio_words:
                    for the_category in categories:
                        if the_category in x_word:
                            discard_bio_word_scores[categories.index(the_category)] = 1 + discard_bio_word_scores[categories.index(the_category)]           

                if len(caption_array) ==0:
                    raise Exception("No Words in profile for categorization or Different language")

                # Word2vec computation
                frame = pd.DataFrame()
                frame, top_keywords = compute(caption_array,categories,3)
                # Word2vec for bio
                frame_bio = pd.DataFrame()
                frame_bio,ignore_keywords = compute(bio_array,categories,2)
                # Storing bio scores
                bio_score = frame_bio['Scores'].tolist()
                for sc in range(len(bio_score)):
                    bio_score[sc] = bio_score[sc] + discard_bio_word_scores[sc] 

                # Add up computed score with discarded score
                score_column = frame['Scores'].tolist()
                for ind in range(len(score_column)):
                    score_column[ind] = score_column[ind] + discard_word_scores[ind]

                # Add weighted score of bio in main score
                normalize_bio_score = normalizeSD(bio_score,3)
                for sc in range(len(normalize_bio_score)):
                    if normalize_bio_score[sc] == 1:
                        score_column[sc] = score_column[sc]*2
                frame['Scores'] = score_column

                #Convert to Percentage
                per = frame['Scores'].tolist()
                per_sum = sum(per)
                for x in range(len(per)):
                    temp_number = (float)(per[x])
                    per[x] = round((temp_number/per_sum)*100)
                frame['Percentage'] = per


                #Store profile percentage
                row_df_5 = get_row_pscore(col_name,dfnew,i,frame,genuinity_score,top_keywords,'Percentage')
                profile_percentages = profile_percentages.append(row_df_5,ignore_index=True)
                profile_percentages.to_csv(r'E:\Winkl Mains\Task_4_Recategorisation\DATA\test1.csv',mode='a',header=False,index =False)

                # POST API Request
#                 file = to_dict_api(frame['Percentage'].tolist(),API_categories,top_keywords,dfnew,i)
    #             url = 'http://44.229.68.155/insta_user/add_category_to_insta_user'
    #             y = requests.post(url, data = file,headers={'Authorization': 'Token ruor7REQi9KJz6wIQKDXvwtt'})

    #             if y.status_code !=200:
    #                 raise Exception("Post request error {}".format(y.status_code))

                print("ID no. {} Done! Total {} ids done".format(userid,idsdone))
                idsdone = idsdone +1

            except Exception as Argument:
                # creating/opening a file 
                f = open(r"E:\Winkl Mains\Task_4_Recategorisation\DATA\errorfile.txt", "a") 
                # writing in the file 
                f.write("Userid\t"+str(userid)+"\t: "+str(Argument)+str("\n")) 
                # closing the file 
                f.close()  

        # END of Main Categorization #

        pages = pages +1
#         profile_percentages.to_csv(r'E:\Winkl Mains\Task_4_Recategorisation\DATA\test1.csv',mode='a',header=False,index =False)
        toc = time.perf_counter()
        print(txt.format(pages,last_id,toc-new_tic))
        # Request new page
        x = requests.get('http://44.229.68.155/insta_users/get_uncategorized_accounts?limit=10&current_id='+str(last_id), headers={'Authorization': 'Token ruor7REQi9KJz6wIQKDXvwtt'})
        data = x.json()
        df = pd.DataFrame(data['users'])
        status = x.status_code
    
    except Exception as Argument:
        # creating/opening a file 
        f = open(r"E:\Winkl Mains\Task_4_Recategorisation\DATA\errorfile.txt", "a") 
        # writing in the file 
        f.write("Currently in "+str(pages)+"\t"+str(Argument)+str("\n")) 
        # closing the file 
        f.close()  
    
    

toc = time.perf_counter()
f = open(r"E:\Winkl Mains\Task_4_Recategorisation\DATA\errorfile.txt", "a") 
# writing in the file 
f.write("The model ran in "+str(toc - tic)+" seconds"+str("\n")) 
f.write("Total ids done: "+str(idsdone))
# closing the file 
f.close() 
display(profile_percentages)
# Out:
# ID no. 15004 Done! Total 0 ids done
# ID no. 15011 Done! Total 1 ids done
# ID no. 15017 Done! Total 2 ids done
# ID no. 15022 Done! Total 3 ids done
# ID no. 15025 Done! Total 4 ids done
# ID no. 15026 Done! Total 5 ids done
# ID no. 15030 Done! Total 6 ids done
# ID no. 15033 Done! Total 7 ids done
# ID no. 15041 Done! Total 8 ids done
# ID no. 15063 Done! Total 9 ids done
# Done 1 pages, the last_id is 15063 and time taken 26.89491969999972 seconds
#   user_id                                      url  food  fashion  makeup  \
# 0   15063  https://www.instagram.com/ritika_shyam/   NaN      NaN     NaN
#
#    beauty  lifestyle  luxury  travel  photography  ...  Health  Lifestyle  \
# 0     NaN        NaN     NaN     NaN          NaN  ...     9.0        9.0
#
#    Luxury  Makeup  Parenting  Photography  Self Improvement  Sports  Travel  \
# 0     4.0     7.0        0.0          5.0               0.0     4.0     4.0
#
#    genuinity_score
# 0        66.323907
#
# [1 rows x 43 columns]

# %%
display(profile_percentages.loc[0])
# Out:
# user_id                                                        122728
# url                     https://www.instagram.com/maa_bhukh_lagi_hai/
# Food                                                               43
# Fashion                                                             3
# Makeup                                                              3
# Beauty                                                             10
# Lifestyle                                                           6
# Luxury                                                              3
# Travel                                                              4
# Photography                                                         4
# Fitness                                                             3
# Sports                                                              3
# Gaming                                                              2
# Entertainment                                                       3
# Gadgets & Tech                                                      4
# Finance                                                             4
# Education                                                           2
# Animal/Pet                                                          2
# Health                                                              4
# Art                                                                 0
# Self Improvement                                                    0
# Parenting                                                           0
# Books                                                               0
# genuinity_score                                               52.4774
# top keywords        [maa, hai, lagi, jaipur, food, thali, ghee, ko...
# Name: 0, dtype: object

# %%
ff = normalizeSD(bio_score,3)
print(ff)
# Out:
# [0, 1, 0, 0, 1, 1, 0, 0]
