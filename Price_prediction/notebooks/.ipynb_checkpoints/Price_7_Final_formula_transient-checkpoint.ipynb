# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def new_price_2(followers,eng_rate,story,image,video,reel,carousel):
    eng_num = followers*eng_rate/100
    num_post = story+image+video+reel+carousel
    video_rate = 0.24583049*followers + 0.01875384*eng_num
    if followers <= 10000:
        story_rate = video_rate*0.3
        image_rate = video_rate*0.5
        carousel_rate = video_rate*0.5
        reel_rate = video_rate*1.4
    if 10000 < followers <=50000:
        story_rate = video_rate*0.6
        image_rate = video_rate*0.5
        carousel_rate = video_rate*0.5
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.35
    if 50000 < followers <=100000:
        story_rate = video_rate*0.3
        image_rate = video_rate*0.5
        carousel_rate = video_rate*0.5
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.3
    if 100000 < followers <=300000:
        story_rate = video_rate*0.3
        image_rate = video_rate*0.6
        carousel_rate = video_rate*0.65
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.3
    if 300000 <followers <= 800000 :
        story_rate = video_rate*0.3
        image_rate = video_rate*0.7
        carousel_rate = video_rate*0.75
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.45
    if 800000 <followers <= 1000000  :
        story_rate = video_rate*0.4
        image_rate = video_rate*0.7
        carousel_rate = video_rate*0.75
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.50
    if 1000000 <followers <= 3000000  :
        story_rate = video_rate*0.25
        image_rate = video_rate*0.55
        carousel_rate = video_rate*0.42
        reel_rate = video_rate*1.3
        video_rate = video_rate*1.3
    if followers > 3000000 :
        story_rate = video_rate*0.03
        image_rate = video_rate*0.40
        carousel_rate = video_rate*0.42
        reel_rate = video_rate*0.8
        video_rate = video_rate*0.9
    if followers <=5000000:
        base_amount = story_rate*story+image_rate*image+video_rate*video+reel_rate*reel+carousel_rate*carousel
    if followers>5000000:
        rate_dec = ((followers/1000000)-(5000000/1000000))*7.87272727
        video_rate = 0.24583049*5000000 + 0.01875384*eng_num
        story_rate = video_rate*0.03
        image_rate = video_rate*0.40
        carousel_rate = video_rate*0.42
        reel_rate = video_rate*0.8
        video_rate = video_rate*0.9
        base_amount = story_rate*story+image_rate*image+video_rate*video+reel_rate*reel+carousel_rate*carousel
        base_amount = base_amount*(1+rate_dec/100)
    if eng_rate > 2:
        base_amount = base_amount*(100+(1.14055527*eng_rate))/100
    if num_post>=3:
        discount_amount = base_amount*0.75
        return discount_amount
    else:
        return base_amount

# %%
## Main Function ##
def new_price_4_old(followers,eng_rate,story,image,video,reel,carousel):
    eng_num = followers*eng_rate/100
    num_post = story+image+video+reel+carousel
    video_rate = 0.24583049*followers + 0.01875384*eng_num
    if followers <= 10000:
        story_rate = video_rate*0.3
        image_rate = video_rate*0.5
        carousel_rate = video_rate*0.5
        reel_rate = video_rate*1.4
    if 10000 < followers <=50000:
        story_rate = video_rate*0.6
        image_rate = video_rate*0.5
        carousel_rate = video_rate*0.5
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.35
    if 50000 < followers <=100000:
        story_rate = video_rate*0.3
        image_rate = video_rate*0.5
        carousel_rate = video_rate*0.5
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.3
    if 100000 < followers <=300000:
        story_rate = video_rate*0.3
        image_rate = video_rate*0.6
        carousel_rate = video_rate*0.65
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.3
    if 300000 <followers <= 800000 :
        story_rate = video_rate*0.3
        image_rate = video_rate*0.7
        carousel_rate = video_rate*0.75
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.45
    if 800000 <followers <= 1000000  :
        story_rate = video_rate*0.4
        image_rate = video_rate*0.7
        carousel_rate = video_rate*0.75
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.50
    if 1000000 <followers <= 3000000  :
        story_rate = video_rate*0.25
        image_rate = video_rate*0.55
        carousel_rate = video_rate*0.42
        reel_rate = video_rate*1.3
        video_rate = video_rate*1.3
    if followers <=3000000:
        base_amount = story_rate*story+image_rate*image+video_rate*video+reel_rate*reel+carousel_rate*carousel
    if followers>3000000:
        rate_dec = ((followers/1000000)-(3000000/1000000))*1.5
        video_rate = 0.24583049*5000000 + 0.01875384*eng_num
        story_rate = video_rate*0.03
        image_rate = video_rate*0.40
        carousel_rate = video_rate*0.42
        reel_rate = video_rate*0.8
        video_rate = video_rate*0.9
        base_amount = story_rate*story+image_rate*image+video_rate*video+reel_rate*reel+carousel_rate*carousel
        base_amount = base_amount*(1+rate_dec/100)
    if eng_rate > 2:
        base_amount = base_amount*(100+(1.14055527*eng_rate))/100
    if num_post>=3:
        discount_amount = base_amount*0.75
        return (discount_amount)
    else:
        return (base_amount)

# %%
## Utility Functions ##
def get_units(n):
    temp_n =n
    unit=0
    while temp_n > 9:
        temp_n = round(temp_n/10)
        unit= unit+1
    return unit

def roundoff(number,digit=1):
    temp_num = number
    temp_num = temp_num/(10**digit)
    temp_num = round(temp_num)
    return temp_num*(10**digit)

def range_it(nm):
    low_price = nm*0.9
    high_price = nm*1.05
    low_price = roundoff(low_price,get_units(low_price)-1)
    high_price = roundoff(high_price,get_units(high_price)-1)
    return low_price,high_price

## Main Function ##
def new_price_4(followers,eng_rate,story,image,video,reel,carousel):
    eng_num = followers*eng_rate/100
    num_post = story+image+video+reel+carousel
    video_rate = 0.24583049*followers + 0.01875384*eng_num
    if followers <= 10000:
        story_rate = video_rate*0.3
        image_rate = video_rate*0.5
        carousel_rate = video_rate*0.5
        reel_rate = video_rate*1.4
    if 10000 < followers <=50000:
        story_rate = video_rate*0.6
        image_rate = video_rate*0.5
        carousel_rate = video_rate*0.5
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.35
    if 50000 < followers <=100000:
        story_rate = video_rate*0.3
        image_rate = video_rate*0.5
        carousel_rate = video_rate*0.5
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.3
    if 100000 < followers <=300000:
        story_rate = video_rate*0.3
        image_rate = video_rate*0.6
        carousel_rate = video_rate*0.65
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.3
    if 300000 <followers <= 800000 :
        story_rate = video_rate*0.3
        image_rate = video_rate*0.7
        carousel_rate = video_rate*0.75
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.45
    if 800000 <followers <= 1000000  :
        story_rate = video_rate*0.4
        image_rate = video_rate*0.7
        carousel_rate = video_rate*0.75
        reel_rate = video_rate*1.4
        video_rate = video_rate*1.50
    if 1000000 <followers <= 3000000  :
        story_rate = video_rate*0.25
        image_rate = video_rate*0.55
        carousel_rate = video_rate*0.42
        reel_rate = video_rate*1.3
        video_rate = video_rate*1.3
    if followers <=3000000:
        base_amount = story_rate*story+image_rate*image+video_rate*video+reel_rate*reel+carousel_rate*carousel
    if followers>3000000:
        rate_dec = ((followers/1000000)-(3000000/1000000))*1.5
        video_rate = 0.24583049*5000000 + 0.01875384*eng_num
        story_rate = video_rate*0.03
        image_rate = video_rate*0.40
        carousel_rate = video_rate*0.42
        reel_rate = video_rate*0.8
        video_rate = video_rate*0.9
        base_amount = story_rate*story+image_rate*image+video_rate*video+reel_rate*reel+carousel_rate*carousel
        base_amount = base_amount*(1+rate_dec/100)
    if eng_rate > 2:
        base_amount = base_amount*(100+(1.14055527*eng_rate))/100
    if num_post>=3:
        discount_amount = base_amount*0.75
        return range_it(discount_amount)
    else:
        return range_it(base_amount)

# %%
followers= 3000
eng_rate = 10
story =1
image =0
video =4
reel =0
carousel =0
l,h =new_price_4(followers,eng_rate,story,image,video,reel,carousel)
print(l)
print(h)
# Out:
# 2400
# 2800

# %%
insta_transient = pd.DataFrame(columns =["followers","engagement","type","story","image","carousel","video","reel","amount","low_range_amount","high_range_amount"])
for follow in range(1000,50000,10000):
    for eng in range(5,11,5):
        story,image,carousel,video,reel = 1,0,0,1,0
        amount = new_price_4_old(follow,eng,story,image,video,reel,carousel)
        low_range,high_range = new_price_4(follow,eng,story,image,video,reel,carousel)
        push_dict = {"followers":follow,
                     "engagement":eng,
                     "type":"story & video",
                     "story":story,
                     "image":image,
                     "carousel":carousel,
                     "video":video,
                     "reel":reel,
                     "amount":amount,
                     "low_range_amount":low_range,
                     "high_range_amount":high_range}
        insta_transient = insta_transient.append(push_dict,ignore_index=True)
        story,image,carousel,video,reel = 2,1,0,1,1
        amount = new_price_4_old(follow,eng,story,image,video,reel,carousel)
        low_range,high_range = new_price_4(follow,eng,story,image,video,reel,carousel)
        push_dict = {"followers":follow,
                     "engagement":eng,
                     "type":">3 post",
                     "story":story,
                     "image":image,
                     "carousel":carousel,
                     "video":video,
                     "reel":reel,
                     "amount":amount,
                     "low_range_amount":low_range,
                     "high_range_amount":high_range}
        insta_transient = insta_transient.append(push_dict,ignore_index=True)


for follow in range(50000,100000,20000):
    for eng in range(5,11,5):
        story,image,carousel,video,reel = 1,0,0,1,0
        amount = new_price_4_old(follow,eng,story,image,video,reel,carousel)
        low_range,high_range = new_price_4(follow,eng,story,image,video,reel,carousel)
        push_dict = {"followers":follow,
                     "engagement":eng,
                     "type":"story & video",
                     "story":story,
                     "image":image,
                     "carousel":carousel,
                     "video":video,
                     "reel":reel,
                     "amount":amount,
                     "low_range_amount":low_range,
                     "high_range_amount":high_range}
        insta_transient = insta_transient.append(push_dict,ignore_index=True)
        story,image,carousel,video,reel = 2,1,0,1,1
        amount = new_price_4_old(follow,eng,story,image,video,reel,carousel)
        low_range,high_range = new_price_4(follow,eng,story,image,video,reel,carousel)
        push_dict = {"followers":follow,
                     "engagement":eng,
                     "type":">3 post",
                     "story":story,
                     "image":image,
                     "carousel":carousel,
                     "video":video,
                     "reel":reel,
                     "amount":amount,
                     "low_range_amount":low_range,
                     "high_range_amount":high_range}
        insta_transient = insta_transient.append(push_dict,ignore_index=True)
        
for follow in range(100000,300000,50000):
    for eng in range(5,11,5):
        story,image,carousel,video,reel = 1,0,0,1,0
        amount = new_price_4_old(follow,eng,story,image,video,reel,carousel)
        low_range,high_range = new_price_4(follow,eng,story,image,video,reel,carousel)
        push_dict = {"followers":follow,
                     "engagement":eng,
                     "type":"story & video",
                     "story":story,
                     "image":image,
                     "carousel":carousel,
                     "video":video,
                     "reel":reel,
                     "amount":amount,
                     "low_range_amount":low_range,
                     "high_range_amount":high_range}
        insta_transient = insta_transient.append(push_dict,ignore_index=True)
        story,image,carousel,video,reel = 2,1,0,1,1
        amount = new_price_4_old(follow,eng,story,image,video,reel,carousel)
        low_range,high_range = new_price_4(follow,eng,story,image,video,reel,carousel)
        push_dict = {"followers":follow,
                     "engagement":eng,
                     "type":">3 post",
                     "story":story,
                     "image":image,
                     "carousel":carousel,
                     "video":video,
                     "reel":reel,
                     "amount":amount,
                     "low_range_amount":low_range,
                     "high_range_amount":high_range}
        insta_transient = insta_transient.append(push_dict,ignore_index=True)
        
for follow in range(350000,1000000,100000):
    for eng in range(5,11,5):
        story,image,carousel,video,reel = 1,0,0,1,0
        amount = new_price_4_old(follow,eng,story,image,video,reel,carousel)
        low_range,high_range = new_price_4(follow,eng,story,image,video,reel,carousel)
        push_dict = {"followers":follow,
                     "engagement":eng,
                     "type":"story & video",
                     "story":story,
                     "image":image,
                     "carousel":carousel,
                     "video":video,
                     "reel":reel,
                     "amount":amount,
                     "low_range_amount":low_range,
                     "high_range_amount":high_range}
        insta_transient = insta_transient.append(push_dict,ignore_index=True)
        story,image,carousel,video,reel = 2,1,0,1,1
        amount = new_price_4_old(follow,eng,story,image,video,reel,carousel)
        low_range,high_range = new_price_4(follow,eng,story,image,video,reel,carousel)
        push_dict = {"followers":follow,
                     "engagement":eng,
                     "type":">3 post",
                     "story":story,
                     "image":image,
                     "carousel":carousel,
                     "video":video,
                     "reel":reel,
                     "amount":amount,
                     "low_range_amount":low_range,
                     "high_range_amount":high_range}
        insta_transient = insta_transient.append(push_dict,ignore_index=True)
        
for follow in range(1000000,5000000,500000):
    for eng in range(5,11,5):
        story,image,carousel,video,reel = 1,0,0,1,0
        amount = new_price_4_old(follow,eng,story,image,video,reel,carousel)
        low_range,high_range = new_price_4(follow,eng,story,image,video,reel,carousel)
        push_dict = {"followers":follow,
                     "engagement":eng,
                     "type":"story & video",
                     "story":story,
                     "image":image,
                     "carousel":carousel,
                     "video":video,
                     "reel":reel,
                     "amount":amount,
                     "low_range_amount":low_range,
                     "high_range_amount":high_range}
        insta_transient = insta_transient.append(push_dict,ignore_index=True)
        story,image,carousel,video,reel = 2,1,0,1,1
        amount = new_price_4_old(follow,eng,story,image,video,reel,carousel)
        low_range,high_range = new_price_4(follow,eng,story,image,video,reel,carousel)
        push_dict = {"followers":follow,
                     "engagement":eng,
                     "type":">3 post",
                     "story":story,
                     "image":image,
                     "carousel":carousel,
                     "video":video,
                     "reel":reel,
                     "amount":amount,
                     "low_range_amount":low_range,
                     "high_range_amount":high_range}
        insta_transient = insta_transient.append(push_dict,ignore_index=True)
        
for follow in range(5500000,20000000,1000000):
    for eng in range(5,11,5):
        story,image,carousel,video,reel = 1,0,0,1,0
        amount = new_price_4_old(follow,eng,story,image,video,reel,carousel)
        low_range,high_range = new_price_4(follow,eng,story,image,video,reel,carousel)
        push_dict = {"followers":follow,
                     "engagement":eng,
                     "type":"story & video",
                     "story":story,
                     "image":image,
                     "carousel":carousel,
                     "video":video,
                     "reel":reel,
                     "amount":amount,
                     "low_range_amount":low_range,
                     "high_range_amount":high_range}
        insta_transient = insta_transient.append(push_dict,ignore_index=True)
        story,image,carousel,video,reel = 2,1,0,1,1
        amount = new_price_4_old(follow,eng,story,image,video,reel,carousel)
        low_range,high_range = new_price_4(follow,eng,story,image,video,reel,carousel)
        push_dict = {"followers":follow,
                     "engagement":eng,
                     "type":">3 post",
                     "story":story,
                     "image":image,
                     "carousel":carousel,
                     "video":video,
                     "reel":reel,
                     "amount":amount,
                     "low_range_amount":low_range,
                     "high_range_amount":high_range}
        insta_transient = insta_transient.append(push_dict,ignore_index=True)

display(insta_transient)
insta_transient.to_csv(r'E:\Winkl Mains\Task_2 Price Prediction\DATA\Formula_transient_3.csv')

insta_trans_clean = insta_transient[insta_transient.engagement == 5]
insta_trans_clean = insta_trans_clean[insta_trans_clean.story ==1]
plt.plot(insta_trans_clean['followers'].tolist(), insta_trans_clean['amount'].tolist(),label="amount")
plt.plot(insta_trans_clean['followers'].tolist(), insta_trans_clean['low_range_amount'].tolist(),label="low_range_amount")
plt.plot(insta_trans_clean['followers'].tolist(), insta_trans_clean['high_range_amount'].tolist(),label="high_range_amount")

plt.xlabel('Followers unit-10M')
# Set the y axis label of the current axis.
plt.ylabel('Price')
# Set a title of the current axes.
plt.title('Instagram Transient Pricing Analysis')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#     followers engagement           type story image carousel video reel  \
# 0        1000          5  story & video     1     0        0     1    0
# 1        1000          5        >3 post     2     1        0     1    1
# 2        1000         10  story & video     1     0        0     1    0
# 3        1000         10        >3 post     2     1        0     1    1
# 4       11000          5  story & video     1     0        0     1    0
# ..        ...        ...            ...   ...   ...      ...   ...  ...
# 163  18500000         10        >3 post     2     1        0     1    1
# 164  19500000          5  story & video     1     0        0     1    0
# 165  19500000          5        >3 post     2     1        0     1    1
# 166  19500000         10  story & video     1     0        0     1    0
# 167  19500000         10        >3 post     2     1        0     1    1
#
#            amount low_range_amount high_range_amount
# 0    3.390931e+02              310               360
# 1    6.847072e+02              620               720
# 2    3.587455e+02              320               380
# 3    7.243900e+02              650               760
# 4    5.595036e+03             5000              5900
# ..            ...              ...               ...
# 163  2.811275e+06          2500000           3000000
# 164  1.529779e+06          1400000           1600000
# 165  2.664776e+06          2400000           2800000
# 166  1.635945e+06          1500000           1700000
# 167  2.849711e+06          2600000           3000000
#
# [168 rows x 11 columns]

# %% [markdown]
# # Line PLot Test

# %% [markdown]
# ### Formula 1 | new_price_2

# %%
insta_line_df = pd.read_csv(r'E:\Winkl Mains\Task_2 Price Prediction\DATA\Formula_transient.csv')

# eng =5 story&video
insta_5_sv = insta_line_df[insta_line_df.engagement == 5]
insta_5_sv = insta_5_sv[insta_5_sv.story ==1]
plt.plot(insta_5_sv['followers'].tolist(), insta_5_sv['amount'].tolist(),label="5%eng story&video")

# eng =5 >3post
insta_5_3p = insta_line_df[insta_line_df.engagement == 5]
insta_5_3p = insta_5_3p[insta_5_3p.story ==2]
plt.plot(insta_5_3p['followers'].tolist(), insta_5_3p['amount'].tolist(),label="5%eng >3post")

# eng=10 story&video
insta_10_sv = insta_line_df[insta_line_df.engagement == 10]
insta_10_sv = insta_10_sv[insta_10_sv.story ==1]
plt.plot(insta_10_sv['followers'].tolist(), insta_10_sv['amount'].tolist(),label="10%eng story&video")

#eng=10 >3post
insta_10_3p = insta_line_df[insta_line_df.engagement == 10]
insta_10_3p = insta_10_3p[insta_10_3p.story ==2]
plt.plot(insta_10_3p['followers'].tolist(), insta_10_3p['amount'].tolist(),label="10%eng >3post")

plt.xlabel('Followers unit->10M')
# Set the y axis label of the current axis.
plt.ylabel('Price')
# Set a title of the current axes.
plt.title('Instagram Transient Pricing Analysis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Formula 2 | new_price_4

# %%
insta_line_df = pd.read_csv(r'E:\Winkl Mains\Task_2 Price Prediction\DATA\Formula_transient_2.csv')

# eng =5 story&video
insta_5_sv = insta_line_df[insta_line_df.engagement == 5]
insta_5_sv = insta_5_sv[insta_5_sv.story ==1]
plt.plot(insta_5_sv['followers'].tolist(), insta_5_sv['amount'].tolist(),label="5%eng story&video")

# eng =5 >3post
insta_5_3p = insta_line_df[insta_line_df.engagement == 5]
insta_5_3p = insta_5_3p[insta_5_3p.story ==2]
plt.plot(insta_5_3p['followers'].tolist(), insta_5_3p['amount'].tolist(),label="5%eng >3post")

# eng=10 story&video
insta_10_sv = insta_line_df[insta_line_df.engagement == 10]
insta_10_sv = insta_10_sv[insta_10_sv.story ==1]
plt.plot(insta_10_sv['followers'].tolist(), insta_10_sv['amount'].tolist(),label="10%eng story&video")

#eng=10 >3post
insta_10_3p = insta_line_df[insta_line_df.engagement == 10]
insta_10_3p = insta_10_3p[insta_10_3p.story ==2]
plt.plot(insta_10_3p['followers'].tolist(), insta_10_3p['amount'].tolist(),label="10%eng >3post")

plt.xlabel('Followers unit->10M')
# Set the y axis label of the current axis.
plt.ylabel('Price')
# Set a title of the current axes.
plt.title('Instagram Transient Pricing Analysis')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Round off function

# %%
# Out:
# 6500
# 7600
# 6500
# 7500

# %%
l,h=new_price_4(2000000,9,1,1,1,0,0)
print(l)
print(h)
# Out:
# 770000
# 900000
